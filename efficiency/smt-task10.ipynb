# %%
import re

def extract_conditions(lambda_expr):
    # 不等式条件を抽出する正規表現パターン
    inequality_pattern = r'\(! \((v\d+) = (v\d+)\)\)'
    
    # 等式条件を抽出する正規表現パターン
    equality_pattern = r'\((v\d+) = (\d+)\)'
    
    # 正規表現で条件をマッチング
    inequalities = re.findall(inequality_pattern, lambda_expr)
    equalities = re.findall(equality_pattern, lambda_expr)
    
    # 変数のセットを作成
    variables = set()
    for match in inequalities + equalities:
        variables.add(match[0])
        if match[1].startswith('v'):
            variables.add(match[1])
    
    # 変数リストを作成し、ソート
    variables = sorted(list(variables), key=lambda x: (int(x[1:-1]), x[-1]))
    
    # Z3の変数定義を出力
    print("variables = " + str(variables))
    print("z3_vars = {var: Int(var) for var in variables}")
    print()
    print("# 元の条件をZ3の制約として追加")
    print("conditions = [")
    
    # 不等式条件を Z3 の形式で出力
    for match in inequalities:
        print(f"    (z3_vars[\"{match[0]}\"] != z3_vars[\"{match[1]}\"]),")
    
    # 等式条件を Z3 の形式で出力
    for match in equalities:
        print(f"    (z3_vars[\"{match[0]}\"] == {match[1]}),")
    
    print("]")


task10 = """
(((\v1 -> ((\v2 -> (v1 $ (v2 $ v2))) $ (\v2 -> (v1 $ (v2 $ v2))))) $ (\v2 -> (\v1 -> ((\v11 -> ((\v12 -> ((\v13 -> ((\v14 -> ((\v15 -> ((\v16 -> ((\v17 -> ((\v18 -> ((\v19 -> ((\v21 -> ((\v22 -> ((\v23 -> ((\v24 -> ((\v25 -> ((\v26 -> ((\v27 -> ((\v28 -> ((\v29 -> ((\v31 -> ((\v32 -> ((\v33 -> ((\v34 -> ((\v35 -> ((\v36 -> ((\v37 -> ((\v38 -> ((\v39 -> ((\v41 -> ((\v42 -> ((\v43 -> ((\v44 -> ((\v45 -> ((\v46 -> ((\v47 -> ((\v48 -> ((\v49 -> ((\v51 -> ((\v52 -> ((\v53 -> ((\v54 -> ((\v55 -> ((\v56 -> ((\v57 -> ((\v58 -> ((\v59 -> ((\v61 -> ((\v62 -> ((\v63 -> ((\v64 -> ((\v65 -> ((\v66 -> ((\v67 -> ((\v68 -> ((\v69 -> ((\v71 -> ((\v72 -> ((\v73 -> ((\v74 -> ((\v75 -> ((\v76 -> ((\v77 -> ((\v78 -> ((\v79 -> ((\v81 -> ((\v82 -> ((\v83 -> ((\v84 -> ((\v85 -> ((\v86 -> ((\v87 -> ((\v88 -> ((\v89 -> ((\v91 -> ((\v92 -> ((\v93 -> ((\v94 -> ((\v95 -> ((\v96 -> ((\v97 -> ((\v98 -> ((\v99 -> ((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((! (v11 = v12)) & (! (v11 = v13))) & (! (v11 = v14))) & (! (v11 = v15))) & (! (v11 = v16))) & (! (v11 = v17))) & (! (v11 = v18))) & (! (v11 = v19))) & (! (v11 = v21))) & (! (v11 = v22))) & (! (v11 = v23))) & (! (v11 = v31))) & (! (v11 = v32))) & (! (v11 = v33))) & (! (v11 = v41))) & (! (v11 = v51))) & (! (v11 = v61))) & (! (v11 = v71))) & (! (v11 = v81))) & (! (v11 = v91))) & (! (v12 = v13))) & (! (v12 = v14))) & (! (v12 = v15))) & (! (v12 = v16))) & (! (v12 = v17))) & (! (v12 = v18))) & (! (v12 = v19))) & (! (v12 = v21))) & (! (v12 = v22))) & (! (v12 = v23))) & (! (v12 = v31))) & (! (v12 = v32))) & (! (v12 = v33))) & (! (v12 = v42))) & (! (v12 = v52))) & (! (v12 = v62))) & (! (v12 = v72))) & (! (v12 = v82))) & (! (v12 = v92))) & (! (v13 = v14))) & (! (v13 = v15))) & (! (v13 = v16))) & (! (v13 = v17))) & (! (v13 = v18))) & (! (v13 = v19))) & (! (v13 = v21))) & (! (v13 = v22))) & (! (v13 = v23))) & (! (v13 = v31))) & (! (v13 = v32))) & (! (v13 = v33))) & (! (v13 = v43))) & (! (v13 = v53))) & (! (v13 = v63))) & (! (v13 = v73))) & (! (v13 = v83))) & (! (v13 = v93))) & (! (v14 = v15))) & (! (v14 = v16))) & (! (v14 = v17))) & (! (v14 = v18))) & (! (v14 = v19))) & (! (v14 = v24))) & (! (v14 = v25))) & (! (v14 = v26))) & (! (v14 = v34))) & (! (v14 = v35))) & (! (v14 = v36))) & (! (v14 = v44))) & (! (v14 = v54))) & (! (v14 = v64))) & (! (v14 = v74))) & (! (v14 = v84))) & (! (v14 = v94))) & (! (v15 = v16))) & (! (v15 = v17))) & (! (v15 = v18))) & (! (v15 = v19))) & (! (v15 = v24))) & (! (v15 = v25))) & (! (v15 = v26))) & (! (v15 = v34))) & (! (v15 = v35))) & (! (v15 = v36))) & (! (v15 = v45))) & (! (v15 = v55))) & (! (v15 = v65))) & (! (v15 = v75))) & (! (v15 = v85))) & (! (v15 = v95))) & (! (v16 = v17))) & (! (v16 = v18))) & (! (v16 = v19))) & (! (v16 = v24))) & (! (v16 = v25))) & (! (v16 = v26))) & (! (v16 = v34))) & (! (v16 = v35))) & (! (v16 = v36))) & (! (v16 = v46))) & (! (v16 = v56))) & (! (v16 = v66))) & (! (v16 = v76))) & (! (v16 = v86))) & (! (v16 = v96))) & (! (v17 = v18))) & (! (v17 = v19))) & (! (v17 = v27))) & (! (v17 = v28))) & (! (v17 = v29))) & (! (v17 = v37))) & (! (v17 = v38))) & (! (v17 = v39))) & (! (v17 = v47))) & (! (v17 = v57))) & (! (v17 = v67))) & (! (v17 = v77))) & (! (v17 = v87))) & (! (v17 = v97))) & (! (v18 = v19))) & (! (v18 = v27))) & (! (v18 = v28))) & (! (v18 = v29))) & (! (v18 = v37))) & (! (v18 = v38))) & (! (v18 = v39))) & (! (v18 = v48))) & (! (v18 = v58))) & (! (v18 = v68))) & (! (v18 = v78))) & (! (v18 = v88))) & (! (v18 = v98))) & (! (v19 = v27))) & (! (v19 = v28))) & (! (v19 = v29))) & (! (v19 = v37))) & (! (v19 = v38))) & (! (v19 = v39))) & (! (v19 = v49))) & (! (v19 = v59))) & (! (v19 = v69))) & (! (v19 = v79))) & (! (v19 = v89))) & (! (v19 = v99))) & (! (v21 = v22))) & (! (v21 = v23))) & (! (v21 = v24))) & (! (v21 = v25))) & (! (v21 = v26))) & (! (v21 = v27))) & (! (v21 = v28))) & (! (v21 = v29))) & (! (v21 = v31))) & (! (v21 = v32))) & (! (v21 = v33))) & (! (v21 = v41))) & (! (v21 = v51))) & (! (v21 = v61))) & (! (v21 = v71))) & (! (v21 = v81))) & (! (v21 = v91))) & (! (v22 = v23))) & (! (v22 = v24))) & (! (v22 = v25))) & (! (v22 = v26))) & (! (v22 = v27))) & (! (v22 = v28))) & (! (v22 = v29))) & (! (v22 = v31))) & (! (v22 = v32))) & (! (v22 = v33))) & (! (v22 = v42))) & (! (v22 = v52))) & (! (v22 = v62))) & (! (v22 = v72))) & (! (v22 = v82))) & (! (v22 = v92))) & (! (v23 = v24))) & (! (v23 = v25))) & (! (v23 = v26))) & (! (v23 = v27))) & (! (v23 = v28))) & (! (v23 = v29))) & (! (v23 = v31))) & (! (v23 = v32))) & (! (v23 = v33))) & (! (v23 = v43))) & (! (v23 = v53))) & (! (v23 = v63))) & (! (v23 = v73))) & (! (v23 = v83))) & (! (v23 = v93))) & (! (v24 = v25))) & (! (v24 = v26))) & (! (v24 = v27))) & (! (v24 = v28))) & (! (v24 = v29))) & (! (v24 = v34))) & (! (v24 = v35))) & (! (v24 = v36))) & (! (v24 = v44))) & (! (v24 = v54))) & (! (v24 = v64))) & (! (v24 = v74))) & (! (v24 = v84))) & (! (v24 = v94))) & (! (v25 = v26))) & (! (v25 = v27))) & (! (v25 = v28))) & (! (v25 = v29))) & (! (v25 = v34))) & (! (v25 = v35))) & (! (v25 = v36))) & (! (v25 = v45))) & (! (v25 = v55))) & (! (v25 = v65))) & (! (v25 = v75))) & (! (v25 = v85))) & (! (v25 = v95))) & (! (v26 = v27))) & (! (v26 = v28))) & (! (v26 = v29))) & (! (v26 = v34))) & (! (v26 = v35))) & (! (v26 = v36))) & (! (v26 = v46))) & (! (v26 = v56))) & (! (v26 = v66))) & (! (v26 = v76))) & (! (v26 = v86))) & (! (v26 = v96))) & (! (v27 = v28))) & (! (v27 = v29))) & (! (v27 = v37))) & (! (v27 = v38))) & (! (v27 = v39))) & (! (v27 = v47))) & (! (v27 = v57))) & (! (v27 = v67))) & (! (v27 = v77))) & (! (v27 = v87))) & (! (v27 = v97))) & (! (v28 = v29))) & (! (v28 = v37))) & (! (v28 = v38))) & (! (v28 = v39))) & (! (v28 = v48))) & (! (v28 = v58))) & (! (v28 = v68))) & (! (v28 = v78))) & (! (v28 = v88))) & (! (v28 = v98))) & (! (v29 = v37))) & (! (v29 = v38))) & (! (v29 = v39))) & (! (v29 = v49))) & (! (v29 = v59))) & (! (v29 = v69))) & (! (v29 = v79))) & (! (v29 = v89))) & (! (v29 = v99))) & (! (v31 = v32))) & (! (v31 = v33))) & (! (v31 = v34))) & (! (v31 = v35))) & (! (v31 = v36))) & (! (v31 = v37))) & (! (v31 = v38))) & (! (v31 = v39))) & (! (v31 = v41))) & (! (v31 = v51))) & (! (v31 = v61))) & (! (v31 = v71))) & (! (v31 = v81))) & (! (v31 = v91))) & (! (v32 = v33))) & (! (v32 = v34))) & (! (v32 = v35))) & (! (v32 = v36))) & (! (v32 = v37))) & (! (v32 = v38))) & (! (v32 = v39))) & (! (v32 = v42))) & (! (v32 = v52))) & (! (v32 = v62))) & (! (v32 = v72))) & (! (v32 = v82))) & (! (v32 = v92))) & (! (v33 = v34))) & (! (v33 = v35))) & (! (v33 = v36))) & (! (v33 = v37))) & (! (v33 = v38))) & (! (v33 = v39))) & (! (v33 = v43))) & (! (v33 = v53))) & (! (v33 = v63))) & (! (v33 = v73))) & (! (v33 = v83))) & (! (v33 = v93))) & (! (v34 = v35))) & (! (v34 = v36))) & (! (v34 = v37))) & (! (v34 = v38))) & (! (v34 = v39))) & (! (v34 = v44))) & (! (v34 = v54))) & (! (v34 = v64))) & (! (v34 = v74))) & (! (v34 = v84))) & (! (v34 = v94))) & (! (v35 = v36))) & (! (v35 = v37))) & (! (v35 = v38))) & (! (v35 = v39))) & (! (v35 = v45))) & (! (v35 = v55))) & (! (v35 = v65))) & (! (v35 = v75))) & (! (v35 = v85))) & (! (v35 = v95))) & (! (v36 = v37))) & (! (v36 = v38))) & (! (v36 = v39))) & (! (v36 = v46))) & (! (v36 = v56))) & (! (v36 = v66))) & (! (v36 = v76))) & (! (v36 = v86))) & (! (v36 = v96))) & (! (v37 = v38))) & (! (v37 = v39))) & (! (v37 = v47))) & (! (v37 = v57))) & (! (v37 = v67))) & (! (v37 = v77))) & (! (v37 = v87))) & (! (v37 = v97))) & (! (v38 = v39))) & (! (v38 = v48))) & (! (v38 = v58))) & (! (v38 = v68))) & (! (v38 = v78))) & (! (v38 = v88))) & (! (v38 = v98))) & (! (v39 = v49))) & (! (v39 = v59))) & (! (v39 = v69))) & (! (v39 = v79))) & (! (v39 = v89))) & (! (v39 = v99))) & (! (v41 = v42))) & (! (v41 = v43))) & (! (v41 = v44))) & (! (v41 = v45))) & (! (v41 = v46))) & (! (v41 = v47))) & (! (v41 = v48))) & (! (v41 = v49))) & (! (v41 = v51))) & (! (v41 = v52))) & (! (v41 = v53))) & (! (v41 = v61))) & (! (v41 = v62))) & (! (v41 = v63))) & (! (v41 = v71))) & (! (v41 = v81))) & (! (v41 = v91))) & (! (v42 = v43))) & (! (v42 = v44))) & (! (v42 = v45))) & (! (v42 = v46))) & (! (v42 = v47))) & (! (v42 = v48))) & (! (v42 = v49))) & (! (v42 = v51))) & (! (v42 = v52))) & (! (v42 = v53))) & (! (v42 = v61))) & (! (v42 = v62))) & (! (v42 = v63))) & (! (v42 = v72))) & (! (v42 = v82))) & (! (v42 = v92))) & (! (v43 = v44))) & (! (v43 = v45))) & (! (v43 = v46))) & (! (v43 = v47))) & (! (v43 = v48))) & (! (v43 = v49))) & (! (v43 = v51))) & (! (v43 = v52))) & (! (v43 = v53))) & (! (v43 = v61))) & (! (v43 = v62))) & (! (v43 = v63))) & (! (v43 = v73))) & (! (v43 = v83))) & (! (v43 = v93))) & (! (v44 = v45))) & (! (v44 = v46))) & (! (v44 = v47))) & (! (v44 = v48))) & (! (v44 = v49))) & (! (v44 = v54))) & (! (v44 = v55))) & (! (v44 = v56))) & (! (v44 = v64))) & (! (v44 = v65))) & (! (v44 = v66))) & (! (v44 = v74))) & (! (v44 = v84))) & (! (v44 = v94))) & (! (v45 = v46))) & (! (v45 = v47))) & (! (v45 = v48))) & (! (v45 = v49))) & (! (v45 = v54))) & (! (v45 = v55))) & (! (v45 = v56))) & (! (v45 = v64))) & (! (v45 = v65))) & (! (v45 = v66))) & (! (v45 = v75))) & (! (v45 = v85))) & (! (v45 = v95))) & (! (v46 = v47))) & (! (v46 = v48))) & (! (v46 = v49))) & (! (v46 = v54))) & (! (v46 = v55))) & (! (v46 = v56))) & (! (v46 = v64))) & (! (v46 = v65))) & (! (v46 = v66))) & (! (v46 = v76))) & (! (v46 = v86))) & (! (v46 = v96))) & (! (v47 = v48))) & (! (v47 = v49))) & (! (v47 = v57))) & (! (v47 = v58))) & (! (v47 = v59))) & (! (v47 = v67))) & (! (v47 = v68))) & (! (v47 = v69))) & (! (v47 = v77))) & (! (v47 = v87))) & (! (v47 = v97))) & (! (v48 = v49))) & (! (v48 = v57))) & (! (v48 = v58))) & (! (v48 = v59))) & (! (v48 = v67))) & (! (v48 = v68))) & (! (v48 = v69))) & (! (v48 = v78))) & (! (v48 = v88))) & (! (v48 = v98))) & (! (v49 = v57))) & (! (v49 = v58))) & (! (v49 = v59))) & (! (v49 = v67))) & (! (v49 = v68))) & (! (v49 = v69))) & (! (v49 = v79))) & (! (v49 = v89))) & (! (v49 = v99))) & (! (v51 = v52))) & (! (v51 = v53))) & (! (v51 = v54))) & (! (v51 = v55))) & (! (v51 = v56))) & (! (v51 = v57))) & (! (v51 = v58))) & (! (v51 = v59))) & (! (v51 = v61))) & (! (v51 = v62))) & (! (v51 = v63))) & (! (v51 = v71))) & (! (v51 = v81))) & (! (v51 = v91))) & (! (v52 = v53))) & (! (v52 = v54))) & (! (v52 = v55))) & (! (v52 = v56))) & (! (v52 = v57))) & (! (v52 = v58))) & (! (v52 = v59))) & (! (v52 = v61))) & (! (v52 = v62))) & (! (v52 = v63))) & (! (v52 = v72))) & (! (v52 = v82))) & (! (v52 = v92))) & (! (v53 = v54))) & (! (v53 = v55))) & (! (v53 = v56))) & (! (v53 = v57))) & (! (v53 = v58))) & (! (v53 = v59))) & (! (v53 = v61))) & (! (v53 = v62))) & (! (v53 = v63))) & (! (v53 = v73))) & (! (v53 = v83))) & (! (v53 = v93))) & (! (v54 = v55))) & (! (v54 = v56))) & (! (v54 = v57))) & (! (v54 = v58))) & (! (v54 = v59))) & (! (v54 = v64))) & (! (v54 = v65))) & (! (v54 = v66))) & (! (v54 = v74))) & (! (v54 = v84))) & (! (v54 = v94))) & (! (v55 = v56))) & (! (v55 = v57))) & (! (v55 = v58))) & (! (v55 = v59))) & (! (v55 = v64))) & (! (v55 = v65))) & (! (v55 = v66))) & (! (v55 = v75))) & (! (v55 = v85))) & (! (v55 = v95))) & (! (v56 = v57))) & (! (v56 = v58))) & (! (v56 = v59))) & (! (v56 = v64))) & (! (v56 = v65))) & (! (v56 = v66))) & (! (v56 = v76))) & (! (v56 = v86))) & (! (v56 = v96))) & (! (v57 = v58))) & (! (v57 = v59))) & (! (v57 = v67))) & (! (v57 = v68))) & (! (v57 = v69))) & (! (v57 = v77))) & (! (v57 = v87))) & (! (v57 = v97))) & (! (v58 = v59))) & (! (v58 = v67))) & (! (v58 = v68))) & (! (v58 = v69))) & (! (v58 = v78))) & (! (v58 = v88))) & (! (v58 = v98))) & (! (v59 = v67))) & (! (v59 = v68))) & (! (v59 = v69))) & (! (v59 = v79))) & (! (v59 = v89))) & (! (v59 = v99))) & (! (v61 = v62))) & (! (v61 = v63))) & (! (v61 = v64))) & (! (v61 = v65))) & (! (v61 = v66))) & (! (v61 = v67))) & (! (v61 = v68))) & (! (v61 = v69))) & (! (v61 = v71))) & (! (v61 = v81))) & (! (v61 = v91))) & (! (v62 = v63))) & (! (v62 = v64))) & (! (v62 = v65))) & (! (v62 = v66))) & (! (v62 = v67))) & (! (v62 = v68))) & (! (v62 = v69))) & (! (v62 = v72))) & (! (v62 = v82))) & (! (v62 = v92))) & (! (v63 = v64))) & (! (v63 = v65))) & (! (v63 = v66))) & (! (v63 = v67))) & (! (v63 = v68))) & (! (v63 = v69))) & (! (v63 = v73))) & (! (v63 = v83))) & (! (v63 = v93))) & (! (v64 = v65))) & (! (v64 = v66))) & (! (v64 = v67))) & (! (v64 = v68))) & (! (v64 = v69))) & (! (v64 = v74))) & (! (v64 = v84))) & (! (v64 = v94))) & (! (v65 = v66))) & (! (v65 = v67))) & (! (v65 = v68))) & (! (v65 = v69))) & (! (v65 = v75))) & (! (v65 = v85))) & (! (v65 = v95))) & (! (v66 = v67))) & (! (v66 = v68))) & (! (v66 = v69))) & (! (v66 = v76))) & (! (v66 = v86))) & (! (v66 = v96))) & (! (v67 = v68))) & (! (v67 = v69))) & (! (v67 = v77))) & (! (v67 = v87))) & (! (v67 = v97))) & (! (v68 = v69))) & (! (v68 = v78))) & (! (v68 = v88))) & (! (v68 = v98))) & (! (v69 = v79))) & (! (v69 = v89))) & (! (v69 = v99))) & (! (v71 = v72))) & (! (v71 = v73))) & (! (v71 = v74))) & (! (v71 = v75))) & (! (v71 = v76))) & (! (v71 = v77))) & (! (v71 = v78))) & (! (v71 = v79))) & (! (v71 = v81))) & (! (v71 = v82))) & (! (v71 = v83))) & (! (v71 = v91))) & (! (v71 = v92))) & (! (v71 = v93))) & (! (v72 = v73))) & (! (v72 = v74))) & (! (v72 = v75))) & (! (v72 = v76))) & (! (v72 = v77))) & (! (v72 = v78))) & (! (v72 = v79))) & (! (v72 = v81))) & (! (v72 = v82))) & (! (v72 = v83))) & (! (v72 = v91))) & (! (v72 = v92))) & (! (v72 = v93))) & (! (v73 = v74))) & (! (v73 = v75))) & (! (v73 = v76))) & (! (v73 = v77))) & (! (v73 = v78))) & (! (v73 = v79))) & (! (v73 = v81))) & (! (v73 = v82))) & (! (v73 = v83))) & (! (v73 = v91))) & (! (v73 = v92))) & (! (v73 = v93))) & (! (v74 = v75))) & (! (v74 = v76))) & (! (v74 = v77))) & (! (v74 = v78))) & (! (v74 = v79))) & (! (v74 = v84))) & (! (v74 = v85))) & (! (v74 = v86))) & (! (v74 = v94))) & (! (v74 = v95))) & (! (v74 = v96))) & (! (v75 = v76))) & (! (v75 = v77))) & (! (v75 = v78))) & (! (v75 = v79))) & (! (v75 = v84))) & (! (v75 = v85))) & (! (v75 = v86))) & (! (v75 = v94))) & (! (v75 = v95))) & (! (v75 = v96))) & (! (v76 = v77))) & (! (v76 = v78))) & (! (v76 = v79))) & (! (v76 = v84))) & (! (v76 = v85))) & (! (v76 = v86))) & (! (v76 = v94))) & (! (v76 = v95))) & (! (v76 = v96))) & (! (v77 = v78))) & (! (v77 = v79))) & (! (v77 = v87))) & (! (v77 = v88))) & (! (v77 = v89))) & (! (v77 = v97))) & (! (v77 = v98))) & (! (v77 = v99))) & (! (v78 = v79))) & (! (v78 = v87))) & (! (v78 = v88))) & (! (v78 = v89))) & (! (v78 = v97))) & (! (v78 = v98))) & (! (v78 = v99))) & (! (v79 = v87))) & (! (v79 = v88))) & (! (v79 = v89))) & (! (v79 = v97))) & (! (v79 = v98))) & (! (v79 = v99))) & (! (v81 = v82))) & (! (v81 = v83))) & (! (v81 = v84))) & (! (v81 = v85))) & (! (v81 = v86))) & (! (v81 = v87))) & (! (v81 = v88))) & (! (v81 = v89))) & (! (v81 = v91))) & (! (v81 = v92))) & (! (v81 = v93))) & (! (v82 = v83))) & (! (v82 = v84))) & (! (v82 = v85))) & (! (v82 = v86))) & (! (v82 = v87))) & (! (v82 = v88))) & (! (v82 = v89))) & (! (v82 = v91))) & (! (v82 = v92))) & (! (v82 = v93))) & (! (v83 = v84))) & (! (v83 = v85))) & (! (v83 = v86))) & (! (v83 = v87))) & (! (v83 = v88))) & (! (v83 = v89))) & (! (v83 = v91))) & (! (v83 = v92))) & (! (v83 = v93))) & (! (v84 = v85))) & (! (v84 = v86))) & (! (v84 = v87))) & (! (v84 = v88))) & (! (v84 = v89))) & (! (v84 = v94))) & (! (v84 = v95))) & (! (v84 = v96))) & (! (v85 = v86))) & (! (v85 = v87))) & (! (v85 = v88))) & (! (v85 = v89))) & (! (v85 = v94))) & (! (v85 = v95))) & (! (v85 = v96))) & (! (v86 = v87))) & (! (v86 = v88))) & (! (v86 = v89))) & (! (v86 = v94))) & (! (v86 = v95))) & (! (v86 = v96))) & (! (v87 = v88))) & (! (v87 = v89))) & (! (v87 = v97))) & (! (v87 = v98))) & (! (v87 = v99))) & (! (v88 = v89))) & (! (v88 = v97))) & (! (v88 = v98))) & (! (v88 = v99))) & (! (v89 = v97))) & (! (v89 = v98))) & (! (v89 = v99))) & (! (v91 = v92))) & (! (v91 = v93))) & (! (v91 = v94))) & (! (v91 = v95))) & (! (v91 = v96))) & (! (v91 = v97))) & (! (v91 = v98))) & (! (v91 = v99))) & (! (v92 = v93))) & (! (v92 = v94))) & (! (v92 = v95))) & (! (v92 = v96))) & (! (v92 = v97))) & (! (v92 = v98))) & (! (v92 = v99))) & (! (v93 = v94))) & (! (v93 = v95))) & (! (v93 = v96))) & (! (v93 = v97))) & (! (v93 = v98))) & (! (v93 = v99))) & (! (v94 = v95))) & (! (v94 = v96))) & (! (v94 = v97))) & (! (v94 = v98))) & (! (v94 = v99))) & (! (v95 = v96))) & (! (v95 = v97))) & (! (v95 = v98))) & (! (v95 = v99))) & (! (v96 = v97))) & (! (v96 = v98))) & (! (v96 = v99))) & (! (v97 = v98))) & (! (v97 = v99))) & (! (v98 = v99))) & (v17 = 6)) & (v18 = 8)) & (v25 = 7)) & (v26 = 3)) & (v29 = 9)) & (v31 = 3)) & (v33 = 9)) & (v38 = 4)) & (v39 = 5)) & (v41 = 4)) & (v42 = 9)) & (v51 = 8)) & (v53 = 3)) & (v55 = 5)) & (v57 = 9)) & (v59 = 2)) & (v68 = 3)) & (v69 = 6)) & (v71 = 9)) & (v72 = 6)) & (v77 = 3)) & (v79 = 8)) & (v81 = 7)) & (v84 = 6)) & (v85 = 8)) & (v92 = 2)) & (v93 = 8)) ? v1 : (v2 $ (v1 + 1)))) $ (1 + ((v1 / 1) % 9)))) $ (1 + ((v1 / 9) % 9)))) $ (1 + ((v1 / 81) % 9)))) $ (1 + ((v1 / 729) % 9)))) $ (1 + ((v1 / 6561) % 9)))) $ (1 + ((v1 / 59049) % 9)))) $ (1 + ((v1 / 531441) % 9)))) $ (1 + ((v1 / 4782969) % 9)))) $ (1 + ((v1 / 43046721) % 9)))) $ (1 + ((v1 / 387420489) % 9)))) $ (1 + ((v1 / 3486784401) % 9)))) $ (1 + ((v1 / 31381059609) % 9)))) $ (1 + ((v1 / 282429536481) % 9)))) $ (1 + ((v1 / 2541865828329) % 9)))) $ (1 + ((v1 / 22876792454961) % 9)))) $ (1 + ((v1 / 205891132094649) % 9)))) $ (1 + ((v1 / 1853020188851841) % 9)))) $ (1 + ((v1 / 16677181699666569) % 9)))) $ (1 + ((v1 / 150094635296999121) % 9)))) $ (1 + ((v1 / 1350851717672992089) % 9)))) $ (1 + ((v1 / 12157665459056928801) % 9)))) $ (1 + ((v1 / 109418989131512359209) % 9)))) $ (1 + ((v1 / 984770902183611232881) % 9)))) $ (1 + ((v1 / 8862938119652501095929) % 9)))) $ (1 + ((v1 / 79766443076872509863361) % 9)))) $ (1 + ((v1 / 717897987691852588770249) % 9)))) $ (1 + ((v1 / 6461081889226673298932241) % 9)))) $ (1 + ((v1 / 58149737003040059690390169) % 9)))) $ (1 + ((v1 / 523347633027360537213511521) % 9)))) $ (1 + ((v1 / 4710128697246244834921603689) % 9)))) $ (1 + ((v1 / 42391158275216203514294433201) % 9)))) $ (1 + ((v1 / 381520424476945831628649898809) % 9)))) $ (1 + ((v1 / 3433683820292512484657849089281) % 9)))) $ (1 + ((v1 / 30903154382632612361920641803529) % 9)))) $ (1 + ((v1 / 278128389443693511257285776231761) % 9)))) $ (1 + ((v1 / 2503155504993241601315571986085849) % 9)))) $ (1 + ((v1 / 22528399544939174411840147874772641) % 9)))) $ (1 + ((v1 / 202755595904452569706561330872953769) % 9)))) $ (1 + ((v1 / 1824800363140073127359051977856583921) % 9)))) $ (1 + ((v1 / 16423203268260658146231467800709255289) % 9)))) $ (1 + ((v1 / 147808829414345923316083210206383297601) % 9)))) $ (1 + ((v1 / 1330279464729113309844748891857449678409) % 9)))) $ (1 + ((v1 / 11972515182562019788602740026717047105681) % 9)))) $ (1 + ((v1 / 107752636643058178097424660240453423951129) % 9)))) $ (1 + ((v1 / 969773729787523602876821942164080815560161) % 9)))) $ (1 + ((v1 / 8727963568087712425891397479476727340041449) % 9)))) $ (1 + ((v1 / 78551672112789411833022577315290546060373041) % 9)))) $ (1 + ((v1 / 706965049015104706497203195837614914543357369) % 9)))) $ (1 + ((v1 / 6362685441135942358474828762538534230890216321) % 9)))) $ (1 + ((v1 / 57264168970223481226273458862846808078011946889) % 9)))) $ (1 + ((v1 / 515377520732011331036461129765621272702107522001) % 9)))) $ (1 + ((v1 / 4638397686588101979328150167890591454318967698009) % 9)))) $ (1 + ((v1 / 41745579179292917813953351511015323088870709282081) % 9)))) $ (1 + ((v1 / 375710212613636260325580163599137907799836383538729) % 9)))) $ (1 + ((v1 / 3381391913522726342930221472392241170198527451848561) % 9)))) $ (1 + ((v1 / 30432527221704537086371993251530170531786747066637049) % 9)))) $ (1 + ((v1 / 273892744995340833777347939263771534786080723599733441) % 9)))) $ (1 + ((v1 / 2465034704958067503996131453373943813074726512397600969) % 9)))) $ (1 + ((v1 / 22185312344622607535965183080365494317672538611578408721) % 9)))) $ (1 + ((v1 / 199667811101603467823686647723289448859052847504205678489) % 9)))) $ (1 + ((v1 / 1797010299914431210413179829509605039731475627537851106401) % 9)))) $ (1 + ((v1 / 16173092699229880893718618465586445357583280647840659957609) % 9)))) $ (1 + ((v1 / 145557834293068928043467566190278008218249525830565939618481) % 9)))) $ (1 + ((v1 / 1310020508637620352391208095712502073964245732475093456566329) % 9)))) $ (1 + ((v1 / 11790184577738583171520872861412518665678211592275841109096961) % 9)))) $ (1 + ((v1 / 106111661199647248543687855752712667991103904330482569981872649) % 9)))) $ (1 + ((v1 / 955004950796825236893190701774414011919935138974343129836853841) % 9)))) $ (1 + ((v1 / 8595044557171427132038716315969726107279416250769088168531684569) % 9)))) $ (1 + ((v1 / 77355401014542844188348446843727534965514746256921793516785161121) % 9)))) $ (1 + ((v1 / 696198609130885597695136021593547814689632716312296141651066450089) % 9)))) $ (1 + ((v1 / 6265787482177970379256224194341930332206694446810665274859598050801) % 9)))) $ (1 + ((v1 / 56392087339601733413306017749077372989860250021295987473736382457209) % 9)))) $ (1 + ((v1 / 507528786056415600719754159741696356908742250191663887263627442114881) % 9)))) $ (1 + ((v1 / 4567759074507740406477787437675267212178680251724974985372646979033929) % 9)))) $ (1 + ((v1 / 41109831670569663658300086939077404909608122265524774868353822811305361) % 9)))) $ (1 + ((v1 / 369988485035126972924700782451696644186473100389722973815184405301748249) % 9)))) $ (1 + ((v1 / 3329896365316142756322307042065269797678257903507506764336659647715734241) % 9)))) $ (1 + ((v1 / 29969067287845284806900763378587428179104321131567560879029936829441608169) % 9)))) $ (1 + ((v1 / 269721605590607563262106870407286853611938890184108047911269431464974473521) % 9)))) $ (1 + ((v1 / 2427494450315468069358961833665581682507450011656972431201424883184770261689) % 9)))) $ (1 + ((v1 / 21847450052839212624230656502990235142567050104912751880812823948662932355201) % 9)))))) $ 1)
""".strip()



extract_conditions(task10)
# Out:
# variables = ['v11', 'v12', 'v13', 'v14', 'v15', 'v16', 'v17', 'v18', 'v19', 'v21', 'v22', 'v23', 'v24', 'v25', 'v26', 'v27', 'v28', 'v29', 'v31', 'v32', 'v33', 'v34', 'v35', 'v36', 'v37', 'v38', 'v39', 'v41', 'v42', 'v43', 'v44', 'v45', 'v46', 'v47', 'v48', 'v49', 'v51', 'v52', 'v53', 'v54', 'v55', 'v56', 'v57', 'v58', 'v59', 'v61', 'v62', 'v63', 'v64', 'v65', 'v66', 'v67', 'v68', 'v69', 'v71', 'v72', 'v73', 'v74', 'v75', 'v76', 'v77', 'v78', 'v79', 'v81', 'v82', 'v83', 'v84', 'v85', 'v86', 'v87', 'v88', 'v89', 'v91', 'v92', 'v93', 'v94', 'v95', 'v96', 'v97', 'v98', 'v99']
# z3_vars = {var: Int(var) for var in variables}
#
# # 元の条件をZ3の制約として追加
# conditions = [
#     (z3_vars["v11"] != z3_vars["v12"]),
#     (z3_vars["v11"] != z3_vars["v13"]),
#     (z3_vars["v11"] != z3_vars["v14"]),
#     (z3_vars["v11"] != z3_vars["v15"]),
#     (z3_vars["v11"] != z3_vars["v16"]),
#     (z3_vars["v11"] != z3_vars["v17"]),
#     (z3_vars["v11"] != z3_vars["v18"]),
# ...

# %%
from z3 import *

variables = sorted(['v11', 'v12', 'v13', 'v14', 'v15', 'v16', 'v17', 'v18', 'v19', 'v21', 'v22', 'v23', 'v24', 'v25', 'v26', 'v27', 'v28', 'v29', 'v31', 'v32', 'v33', 'v34', 'v35', 'v36', 'v37', 'v38', 'v39', 'v41', 'v42', 'v43', 'v44', 'v45', 'v46', 'v47', 'v48', 'v49', 'v51', 'v52', 'v53', 'v54', 'v55', 'v56', 'v57', 'v58', 'v59', 'v61', 'v62', 'v63', 'v64', 'v65', 'v66', 'v67', 'v68', 'v69', 'v71', 'v72', 'v73', 'v74', 'v75', 'v76', 'v77', 'v78', 'v79', 'v81', 'v82', 'v83', 'v84', 'v85', 'v86', 'v87', 'v88', 'v89', 'v91', 'v92', 'v93', 'v94', 'v95', 'v96', 'v97', 'v98', 'v99'])
z3_vars = {var: Int(var) for var in variables}

# 元の条件をZ3の制約として追加
conditions = [
    (z3_vars["v11"] != z3_vars["v12"]),
    (z3_vars["v11"] != z3_vars["v13"]),
    (z3_vars["v11"] != z3_vars["v14"]),
    (z3_vars["v11"] != z3_vars["v15"]),
    (z3_vars["v11"] != z3_vars["v16"]),
    (z3_vars["v11"] != z3_vars["v17"]),
    (z3_vars["v11"] != z3_vars["v18"]),
    (z3_vars["v11"] != z3_vars["v19"]),
    (z3_vars["v11"] != z3_vars["v21"]),
    (z3_vars["v11"] != z3_vars["v22"]),
    (z3_vars["v11"] != z3_vars["v23"]),
    (z3_vars["v11"] != z3_vars["v31"]),
    (z3_vars["v11"] != z3_vars["v32"]),
    (z3_vars["v11"] != z3_vars["v33"]),
    (z3_vars["v11"] != z3_vars["v41"]),
    (z3_vars["v11"] != z3_vars["v51"]),
    (z3_vars["v11"] != z3_vars["v61"]),
    (z3_vars["v11"] != z3_vars["v71"]),
    (z3_vars["v11"] != z3_vars["v81"]),
    (z3_vars["v11"] != z3_vars["v91"]),
    (z3_vars["v12"] != z3_vars["v13"]),
    (z3_vars["v12"] != z3_vars["v14"]),
    (z3_vars["v12"] != z3_vars["v15"]),
    (z3_vars["v12"] != z3_vars["v16"]),
    (z3_vars["v12"] != z3_vars["v17"]),
    (z3_vars["v12"] != z3_vars["v18"]),
    (z3_vars["v12"] != z3_vars["v19"]),
    (z3_vars["v12"] != z3_vars["v21"]),
    (z3_vars["v12"] != z3_vars["v22"]),
    (z3_vars["v12"] != z3_vars["v23"]),
    (z3_vars["v12"] != z3_vars["v31"]),
    (z3_vars["v12"] != z3_vars["v32"]),
    (z3_vars["v12"] != z3_vars["v33"]),
    (z3_vars["v12"] != z3_vars["v42"]),
    (z3_vars["v12"] != z3_vars["v52"]),
    (z3_vars["v12"] != z3_vars["v62"]),
    (z3_vars["v12"] != z3_vars["v72"]),
    (z3_vars["v12"] != z3_vars["v82"]),
    (z3_vars["v12"] != z3_vars["v92"]),
    (z3_vars["v13"] != z3_vars["v14"]),
    (z3_vars["v13"] != z3_vars["v15"]),
    (z3_vars["v13"] != z3_vars["v16"]),
    (z3_vars["v13"] != z3_vars["v17"]),
    (z3_vars["v13"] != z3_vars["v18"]),
    (z3_vars["v13"] != z3_vars["v19"]),
    (z3_vars["v13"] != z3_vars["v21"]),
    (z3_vars["v13"] != z3_vars["v22"]),
    (z3_vars["v13"] != z3_vars["v23"]),
    (z3_vars["v13"] != z3_vars["v31"]),
    (z3_vars["v13"] != z3_vars["v32"]),
    (z3_vars["v13"] != z3_vars["v33"]),
    (z3_vars["v13"] != z3_vars["v43"]),
    (z3_vars["v13"] != z3_vars["v53"]),
    (z3_vars["v13"] != z3_vars["v63"]),
    (z3_vars["v13"] != z3_vars["v73"]),
    (z3_vars["v13"] != z3_vars["v83"]),
    (z3_vars["v13"] != z3_vars["v93"]),
    (z3_vars["v14"] != z3_vars["v15"]),
    (z3_vars["v14"] != z3_vars["v16"]),
    (z3_vars["v14"] != z3_vars["v17"]),
    (z3_vars["v14"] != z3_vars["v18"]),
    (z3_vars["v14"] != z3_vars["v19"]),
    (z3_vars["v14"] != z3_vars["v24"]),
    (z3_vars["v14"] != z3_vars["v25"]),
    (z3_vars["v14"] != z3_vars["v26"]),
    (z3_vars["v14"] != z3_vars["v34"]),
    (z3_vars["v14"] != z3_vars["v35"]),
    (z3_vars["v14"] != z3_vars["v36"]),
    (z3_vars["v14"] != z3_vars["v44"]),
    (z3_vars["v14"] != z3_vars["v54"]),
    (z3_vars["v14"] != z3_vars["v64"]),
    (z3_vars["v14"] != z3_vars["v74"]),
    (z3_vars["v14"] != z3_vars["v84"]),
    (z3_vars["v14"] != z3_vars["v94"]),
    (z3_vars["v15"] != z3_vars["v16"]),
    (z3_vars["v15"] != z3_vars["v17"]),
    (z3_vars["v15"] != z3_vars["v18"]),
    (z3_vars["v15"] != z3_vars["v19"]),
    (z3_vars["v15"] != z3_vars["v24"]),
    (z3_vars["v15"] != z3_vars["v25"]),
    (z3_vars["v15"] != z3_vars["v26"]),
    (z3_vars["v15"] != z3_vars["v34"]),
    (z3_vars["v15"] != z3_vars["v35"]),
    (z3_vars["v15"] != z3_vars["v36"]),
    (z3_vars["v15"] != z3_vars["v45"]),
    (z3_vars["v15"] != z3_vars["v55"]),
    (z3_vars["v15"] != z3_vars["v65"]),
    (z3_vars["v15"] != z3_vars["v75"]),
    (z3_vars["v15"] != z3_vars["v85"]),
    (z3_vars["v15"] != z3_vars["v95"]),
    (z3_vars["v16"] != z3_vars["v17"]),
    (z3_vars["v16"] != z3_vars["v18"]),
    (z3_vars["v16"] != z3_vars["v19"]),
    (z3_vars["v16"] != z3_vars["v24"]),
    (z3_vars["v16"] != z3_vars["v25"]),
    (z3_vars["v16"] != z3_vars["v26"]),
    (z3_vars["v16"] != z3_vars["v34"]),
    (z3_vars["v16"] != z3_vars["v35"]),
    (z3_vars["v16"] != z3_vars["v36"]),
    (z3_vars["v16"] != z3_vars["v46"]),
    (z3_vars["v16"] != z3_vars["v56"]),
    (z3_vars["v16"] != z3_vars["v66"]),
    (z3_vars["v16"] != z3_vars["v76"]),
    (z3_vars["v16"] != z3_vars["v86"]),
    (z3_vars["v16"] != z3_vars["v96"]),
    (z3_vars["v17"] != z3_vars["v18"]),
    (z3_vars["v17"] != z3_vars["v19"]),
    (z3_vars["v17"] != z3_vars["v27"]),
    (z3_vars["v17"] != z3_vars["v28"]),
    (z3_vars["v17"] != z3_vars["v29"]),
    (z3_vars["v17"] != z3_vars["v37"]),
    (z3_vars["v17"] != z3_vars["v38"]),
    (z3_vars["v17"] != z3_vars["v39"]),
    (z3_vars["v17"] != z3_vars["v47"]),
    (z3_vars["v17"] != z3_vars["v57"]),
    (z3_vars["v17"] != z3_vars["v67"]),
    (z3_vars["v17"] != z3_vars["v77"]),
    (z3_vars["v17"] != z3_vars["v87"]),
    (z3_vars["v17"] != z3_vars["v97"]),
    (z3_vars["v18"] != z3_vars["v19"]),
    (z3_vars["v18"] != z3_vars["v27"]),
    (z3_vars["v18"] != z3_vars["v28"]),
    (z3_vars["v18"] != z3_vars["v29"]),
    (z3_vars["v18"] != z3_vars["v37"]),
    (z3_vars["v18"] != z3_vars["v38"]),
    (z3_vars["v18"] != z3_vars["v39"]),
    (z3_vars["v18"] != z3_vars["v48"]),
    (z3_vars["v18"] != z3_vars["v58"]),
    (z3_vars["v18"] != z3_vars["v68"]),
    (z3_vars["v18"] != z3_vars["v78"]),
    (z3_vars["v18"] != z3_vars["v88"]),
    (z3_vars["v18"] != z3_vars["v98"]),
    (z3_vars["v19"] != z3_vars["v27"]),
    (z3_vars["v19"] != z3_vars["v28"]),
    (z3_vars["v19"] != z3_vars["v29"]),
    (z3_vars["v19"] != z3_vars["v37"]),
    (z3_vars["v19"] != z3_vars["v38"]),
    (z3_vars["v19"] != z3_vars["v39"]),
    (z3_vars["v19"] != z3_vars["v49"]),
    (z3_vars["v19"] != z3_vars["v59"]),
    (z3_vars["v19"] != z3_vars["v69"]),
    (z3_vars["v19"] != z3_vars["v79"]),
    (z3_vars["v19"] != z3_vars["v89"]),
    (z3_vars["v19"] != z3_vars["v99"]),
    (z3_vars["v21"] != z3_vars["v22"]),
    (z3_vars["v21"] != z3_vars["v23"]),
    (z3_vars["v21"] != z3_vars["v24"]),
    (z3_vars["v21"] != z3_vars["v25"]),
    (z3_vars["v21"] != z3_vars["v26"]),
    (z3_vars["v21"] != z3_vars["v27"]),
    (z3_vars["v21"] != z3_vars["v28"]),
    (z3_vars["v21"] != z3_vars["v29"]),
    (z3_vars["v21"] != z3_vars["v31"]),
    (z3_vars["v21"] != z3_vars["v32"]),
    (z3_vars["v21"] != z3_vars["v33"]),
    (z3_vars["v21"] != z3_vars["v41"]),
    (z3_vars["v21"] != z3_vars["v51"]),
    (z3_vars["v21"] != z3_vars["v61"]),
    (z3_vars["v21"] != z3_vars["v71"]),
    (z3_vars["v21"] != z3_vars["v81"]),
    (z3_vars["v21"] != z3_vars["v91"]),
    (z3_vars["v22"] != z3_vars["v23"]),
    (z3_vars["v22"] != z3_vars["v24"]),
    (z3_vars["v22"] != z3_vars["v25"]),
    (z3_vars["v22"] != z3_vars["v26"]),
    (z3_vars["v22"] != z3_vars["v27"]),
    (z3_vars["v22"] != z3_vars["v28"]),
    (z3_vars["v22"] != z3_vars["v29"]),
    (z3_vars["v22"] != z3_vars["v31"]),
    (z3_vars["v22"] != z3_vars["v32"]),
    (z3_vars["v22"] != z3_vars["v33"]),
    (z3_vars["v22"] != z3_vars["v42"]),
    (z3_vars["v22"] != z3_vars["v52"]),
    (z3_vars["v22"] != z3_vars["v62"]),
    (z3_vars["v22"] != z3_vars["v72"]),
    (z3_vars["v22"] != z3_vars["v82"]),
    (z3_vars["v22"] != z3_vars["v92"]),
    (z3_vars["v23"] != z3_vars["v24"]),
    (z3_vars["v23"] != z3_vars["v25"]),
    (z3_vars["v23"] != z3_vars["v26"]),
    (z3_vars["v23"] != z3_vars["v27"]),
    (z3_vars["v23"] != z3_vars["v28"]),
    (z3_vars["v23"] != z3_vars["v29"]),
    (z3_vars["v23"] != z3_vars["v31"]),
    (z3_vars["v23"] != z3_vars["v32"]),
    (z3_vars["v23"] != z3_vars["v33"]),
    (z3_vars["v23"] != z3_vars["v43"]),
    (z3_vars["v23"] != z3_vars["v53"]),
    (z3_vars["v23"] != z3_vars["v63"]),
    (z3_vars["v23"] != z3_vars["v73"]),
    (z3_vars["v23"] != z3_vars["v83"]),
    (z3_vars["v23"] != z3_vars["v93"]),
    (z3_vars["v24"] != z3_vars["v25"]),
    (z3_vars["v24"] != z3_vars["v26"]),
    (z3_vars["v24"] != z3_vars["v27"]),
    (z3_vars["v24"] != z3_vars["v28"]),
    (z3_vars["v24"] != z3_vars["v29"]),
    (z3_vars["v24"] != z3_vars["v34"]),
    (z3_vars["v24"] != z3_vars["v35"]),
    (z3_vars["v24"] != z3_vars["v36"]),
    (z3_vars["v24"] != z3_vars["v44"]),
    (z3_vars["v24"] != z3_vars["v54"]),
    (z3_vars["v24"] != z3_vars["v64"]),
    (z3_vars["v24"] != z3_vars["v74"]),
    (z3_vars["v24"] != z3_vars["v84"]),
    (z3_vars["v24"] != z3_vars["v94"]),
    (z3_vars["v25"] != z3_vars["v26"]),
    (z3_vars["v25"] != z3_vars["v27"]),
    (z3_vars["v25"] != z3_vars["v28"]),
    (z3_vars["v25"] != z3_vars["v29"]),
    (z3_vars["v25"] != z3_vars["v34"]),
    (z3_vars["v25"] != z3_vars["v35"]),
    (z3_vars["v25"] != z3_vars["v36"]),
    (z3_vars["v25"] != z3_vars["v45"]),
    (z3_vars["v25"] != z3_vars["v55"]),
    (z3_vars["v25"] != z3_vars["v65"]),
    (z3_vars["v25"] != z3_vars["v75"]),
    (z3_vars["v25"] != z3_vars["v85"]),
    (z3_vars["v25"] != z3_vars["v95"]),
    (z3_vars["v26"] != z3_vars["v27"]),
    (z3_vars["v26"] != z3_vars["v28"]),
    (z3_vars["v26"] != z3_vars["v29"]),
    (z3_vars["v26"] != z3_vars["v34"]),
    (z3_vars["v26"] != z3_vars["v35"]),
    (z3_vars["v26"] != z3_vars["v36"]),
    (z3_vars["v26"] != z3_vars["v46"]),
    (z3_vars["v26"] != z3_vars["v56"]),
    (z3_vars["v26"] != z3_vars["v66"]),
    (z3_vars["v26"] != z3_vars["v76"]),
    (z3_vars["v26"] != z3_vars["v86"]),
    (z3_vars["v26"] != z3_vars["v96"]),
    (z3_vars["v27"] != z3_vars["v28"]),
    (z3_vars["v27"] != z3_vars["v29"]),
    (z3_vars["v27"] != z3_vars["v37"]),
    (z3_vars["v27"] != z3_vars["v38"]),
    (z3_vars["v27"] != z3_vars["v39"]),
    (z3_vars["v27"] != z3_vars["v47"]),
    (z3_vars["v27"] != z3_vars["v57"]),
    (z3_vars["v27"] != z3_vars["v67"]),
    (z3_vars["v27"] != z3_vars["v77"]),
    (z3_vars["v27"] != z3_vars["v87"]),
    (z3_vars["v27"] != z3_vars["v97"]),
    (z3_vars["v28"] != z3_vars["v29"]),
    (z3_vars["v28"] != z3_vars["v37"]),
    (z3_vars["v28"] != z3_vars["v38"]),
    (z3_vars["v28"] != z3_vars["v39"]),
    (z3_vars["v28"] != z3_vars["v48"]),
    (z3_vars["v28"] != z3_vars["v58"]),
    (z3_vars["v28"] != z3_vars["v68"]),
    (z3_vars["v28"] != z3_vars["v78"]),
    (z3_vars["v28"] != z3_vars["v88"]),
    (z3_vars["v28"] != z3_vars["v98"]),
    (z3_vars["v29"] != z3_vars["v37"]),
    (z3_vars["v29"] != z3_vars["v38"]),
    (z3_vars["v29"] != z3_vars["v39"]),
    (z3_vars["v29"] != z3_vars["v49"]),
    (z3_vars["v29"] != z3_vars["v59"]),
    (z3_vars["v29"] != z3_vars["v69"]),
    (z3_vars["v29"] != z3_vars["v79"]),
    (z3_vars["v29"] != z3_vars["v89"]),
    (z3_vars["v29"] != z3_vars["v99"]),
    (z3_vars["v31"] != z3_vars["v32"]),
    (z3_vars["v31"] != z3_vars["v33"]),
    (z3_vars["v31"] != z3_vars["v34"]),
    (z3_vars["v31"] != z3_vars["v35"]),
    (z3_vars["v31"] != z3_vars["v36"]),
    (z3_vars["v31"] != z3_vars["v37"]),
    (z3_vars["v31"] != z3_vars["v38"]),
    (z3_vars["v31"] != z3_vars["v39"]),
    (z3_vars["v31"] != z3_vars["v41"]),
    (z3_vars["v31"] != z3_vars["v51"]),
    (z3_vars["v31"] != z3_vars["v61"]),
    (z3_vars["v31"] != z3_vars["v71"]),
    (z3_vars["v31"] != z3_vars["v81"]),
    (z3_vars["v31"] != z3_vars["v91"]),
    (z3_vars["v32"] != z3_vars["v33"]),
    (z3_vars["v32"] != z3_vars["v34"]),
    (z3_vars["v32"] != z3_vars["v35"]),
    (z3_vars["v32"] != z3_vars["v36"]),
    (z3_vars["v32"] != z3_vars["v37"]),
    (z3_vars["v32"] != z3_vars["v38"]),
    (z3_vars["v32"] != z3_vars["v39"]),
    (z3_vars["v32"] != z3_vars["v42"]),
    (z3_vars["v32"] != z3_vars["v52"]),
    (z3_vars["v32"] != z3_vars["v62"]),
    (z3_vars["v32"] != z3_vars["v72"]),
    (z3_vars["v32"] != z3_vars["v82"]),
    (z3_vars["v32"] != z3_vars["v92"]),
    (z3_vars["v33"] != z3_vars["v34"]),
    (z3_vars["v33"] != z3_vars["v35"]),
    (z3_vars["v33"] != z3_vars["v36"]),
    (z3_vars["v33"] != z3_vars["v37"]),
    (z3_vars["v33"] != z3_vars["v38"]),
    (z3_vars["v33"] != z3_vars["v39"]),
    (z3_vars["v33"] != z3_vars["v43"]),
    (z3_vars["v33"] != z3_vars["v53"]),
    (z3_vars["v33"] != z3_vars["v63"]),
    (z3_vars["v33"] != z3_vars["v73"]),
    (z3_vars["v33"] != z3_vars["v83"]),
    (z3_vars["v33"] != z3_vars["v93"]),
    (z3_vars["v34"] != z3_vars["v35"]),
    (z3_vars["v34"] != z3_vars["v36"]),
    (z3_vars["v34"] != z3_vars["v37"]),
    (z3_vars["v34"] != z3_vars["v38"]),
    (z3_vars["v34"] != z3_vars["v39"]),
    (z3_vars["v34"] != z3_vars["v44"]),
    (z3_vars["v34"] != z3_vars["v54"]),
    (z3_vars["v34"] != z3_vars["v64"]),
    (z3_vars["v34"] != z3_vars["v74"]),
    (z3_vars["v34"] != z3_vars["v84"]),
    (z3_vars["v34"] != z3_vars["v94"]),
    (z3_vars["v35"] != z3_vars["v36"]),
    (z3_vars["v35"] != z3_vars["v37"]),
    (z3_vars["v35"] != z3_vars["v38"]),
    (z3_vars["v35"] != z3_vars["v39"]),
    (z3_vars["v35"] != z3_vars["v45"]),
    (z3_vars["v35"] != z3_vars["v55"]),
    (z3_vars["v35"] != z3_vars["v65"]),
    (z3_vars["v35"] != z3_vars["v75"]),
    (z3_vars["v35"] != z3_vars["v85"]),
    (z3_vars["v35"] != z3_vars["v95"]),
    (z3_vars["v36"] != z3_vars["v37"]),
    (z3_vars["v36"] != z3_vars["v38"]),
    (z3_vars["v36"] != z3_vars["v39"]),
    (z3_vars["v36"] != z3_vars["v46"]),
    (z3_vars["v36"] != z3_vars["v56"]),
    (z3_vars["v36"] != z3_vars["v66"]),
    (z3_vars["v36"] != z3_vars["v76"]),
    (z3_vars["v36"] != z3_vars["v86"]),
    (z3_vars["v36"] != z3_vars["v96"]),
    (z3_vars["v37"] != z3_vars["v38"]),
    (z3_vars["v37"] != z3_vars["v39"]),
    (z3_vars["v37"] != z3_vars["v47"]),
    (z3_vars["v37"] != z3_vars["v57"]),
    (z3_vars["v37"] != z3_vars["v67"]),
    (z3_vars["v37"] != z3_vars["v77"]),
    (z3_vars["v37"] != z3_vars["v87"]),
    (z3_vars["v37"] != z3_vars["v97"]),
    (z3_vars["v38"] != z3_vars["v39"]),
    (z3_vars["v38"] != z3_vars["v48"]),
    (z3_vars["v38"] != z3_vars["v58"]),
    (z3_vars["v38"] != z3_vars["v68"]),
    (z3_vars["v38"] != z3_vars["v78"]),
    (z3_vars["v38"] != z3_vars["v88"]),
    (z3_vars["v38"] != z3_vars["v98"]),
    (z3_vars["v39"] != z3_vars["v49"]),
    (z3_vars["v39"] != z3_vars["v59"]),
    (z3_vars["v39"] != z3_vars["v69"]),
    (z3_vars["v39"] != z3_vars["v79"]),
    (z3_vars["v39"] != z3_vars["v89"]),
    (z3_vars["v39"] != z3_vars["v99"]),
    (z3_vars["v41"] != z3_vars["v42"]),
    (z3_vars["v41"] != z3_vars["v43"]),
    (z3_vars["v41"] != z3_vars["v44"]),
    (z3_vars["v41"] != z3_vars["v45"]),
    (z3_vars["v41"] != z3_vars["v46"]),
    (z3_vars["v41"] != z3_vars["v47"]),
    (z3_vars["v41"] != z3_vars["v48"]),
    (z3_vars["v41"] != z3_vars["v49"]),
    (z3_vars["v41"] != z3_vars["v51"]),
    (z3_vars["v41"] != z3_vars["v52"]),
    (z3_vars["v41"] != z3_vars["v53"]),
    (z3_vars["v41"] != z3_vars["v61"]),
    (z3_vars["v41"] != z3_vars["v62"]),
    (z3_vars["v41"] != z3_vars["v63"]),
    (z3_vars["v41"] != z3_vars["v71"]),
    (z3_vars["v41"] != z3_vars["v81"]),
    (z3_vars["v41"] != z3_vars["v91"]),
    (z3_vars["v42"] != z3_vars["v43"]),
    (z3_vars["v42"] != z3_vars["v44"]),
    (z3_vars["v42"] != z3_vars["v45"]),
    (z3_vars["v42"] != z3_vars["v46"]),
    (z3_vars["v42"] != z3_vars["v47"]),
    (z3_vars["v42"] != z3_vars["v48"]),
    (z3_vars["v42"] != z3_vars["v49"]),
    (z3_vars["v42"] != z3_vars["v51"]),
    (z3_vars["v42"] != z3_vars["v52"]),
    (z3_vars["v42"] != z3_vars["v53"]),
    (z3_vars["v42"] != z3_vars["v61"]),
    (z3_vars["v42"] != z3_vars["v62"]),
    (z3_vars["v42"] != z3_vars["v63"]),
    (z3_vars["v42"] != z3_vars["v72"]),
    (z3_vars["v42"] != z3_vars["v82"]),
    (z3_vars["v42"] != z3_vars["v92"]),
    (z3_vars["v43"] != z3_vars["v44"]),
    (z3_vars["v43"] != z3_vars["v45"]),
    (z3_vars["v43"] != z3_vars["v46"]),
    (z3_vars["v43"] != z3_vars["v47"]),
    (z3_vars["v43"] != z3_vars["v48"]),
    (z3_vars["v43"] != z3_vars["v49"]),
    (z3_vars["v43"] != z3_vars["v51"]),
    (z3_vars["v43"] != z3_vars["v52"]),
    (z3_vars["v43"] != z3_vars["v53"]),
    (z3_vars["v43"] != z3_vars["v61"]),
    (z3_vars["v43"] != z3_vars["v62"]),
    (z3_vars["v43"] != z3_vars["v63"]),
    (z3_vars["v43"] != z3_vars["v73"]),
    (z3_vars["v43"] != z3_vars["v83"]),
    (z3_vars["v43"] != z3_vars["v93"]),
    (z3_vars["v44"] != z3_vars["v45"]),
    (z3_vars["v44"] != z3_vars["v46"]),
    (z3_vars["v44"] != z3_vars["v47"]),
    (z3_vars["v44"] != z3_vars["v48"]),
    (z3_vars["v44"] != z3_vars["v49"]),
    (z3_vars["v44"] != z3_vars["v54"]),
    (z3_vars["v44"] != z3_vars["v55"]),
    (z3_vars["v44"] != z3_vars["v56"]),
    (z3_vars["v44"] != z3_vars["v64"]),
    (z3_vars["v44"] != z3_vars["v65"]),
    (z3_vars["v44"] != z3_vars["v66"]),
    (z3_vars["v44"] != z3_vars["v74"]),
    (z3_vars["v44"] != z3_vars["v84"]),
    (z3_vars["v44"] != z3_vars["v94"]),
    (z3_vars["v45"] != z3_vars["v46"]),
    (z3_vars["v45"] != z3_vars["v47"]),
    (z3_vars["v45"] != z3_vars["v48"]),
    (z3_vars["v45"] != z3_vars["v49"]),
    (z3_vars["v45"] != z3_vars["v54"]),
    (z3_vars["v45"] != z3_vars["v55"]),
    (z3_vars["v45"] != z3_vars["v56"]),
    (z3_vars["v45"] != z3_vars["v64"]),
    (z3_vars["v45"] != z3_vars["v65"]),
    (z3_vars["v45"] != z3_vars["v66"]),
    (z3_vars["v45"] != z3_vars["v75"]),
    (z3_vars["v45"] != z3_vars["v85"]),
    (z3_vars["v45"] != z3_vars["v95"]),
    (z3_vars["v46"] != z3_vars["v47"]),
    (z3_vars["v46"] != z3_vars["v48"]),
    (z3_vars["v46"] != z3_vars["v49"]),
    (z3_vars["v46"] != z3_vars["v54"]),
    (z3_vars["v46"] != z3_vars["v55"]),
    (z3_vars["v46"] != z3_vars["v56"]),
    (z3_vars["v46"] != z3_vars["v64"]),
    (z3_vars["v46"] != z3_vars["v65"]),
    (z3_vars["v46"] != z3_vars["v66"]),
    (z3_vars["v46"] != z3_vars["v76"]),
    (z3_vars["v46"] != z3_vars["v86"]),
    (z3_vars["v46"] != z3_vars["v96"]),
    (z3_vars["v47"] != z3_vars["v48"]),
    (z3_vars["v47"] != z3_vars["v49"]),
    (z3_vars["v47"] != z3_vars["v57"]),
    (z3_vars["v47"] != z3_vars["v58"]),
    (z3_vars["v47"] != z3_vars["v59"]),
    (z3_vars["v47"] != z3_vars["v67"]),
    (z3_vars["v47"] != z3_vars["v68"]),
    (z3_vars["v47"] != z3_vars["v69"]),
    (z3_vars["v47"] != z3_vars["v77"]),
    (z3_vars["v47"] != z3_vars["v87"]),
    (z3_vars["v47"] != z3_vars["v97"]),
    (z3_vars["v48"] != z3_vars["v49"]),
    (z3_vars["v48"] != z3_vars["v57"]),
    (z3_vars["v48"] != z3_vars["v58"]),
    (z3_vars["v48"] != z3_vars["v59"]),
    (z3_vars["v48"] != z3_vars["v67"]),
    (z3_vars["v48"] != z3_vars["v68"]),
    (z3_vars["v48"] != z3_vars["v69"]),
    (z3_vars["v48"] != z3_vars["v78"]),
    (z3_vars["v48"] != z3_vars["v88"]),
    (z3_vars["v48"] != z3_vars["v98"]),
    (z3_vars["v49"] != z3_vars["v57"]),
    (z3_vars["v49"] != z3_vars["v58"]),
    (z3_vars["v49"] != z3_vars["v59"]),
    (z3_vars["v49"] != z3_vars["v67"]),
    (z3_vars["v49"] != z3_vars["v68"]),
    (z3_vars["v49"] != z3_vars["v69"]),
    (z3_vars["v49"] != z3_vars["v79"]),
    (z3_vars["v49"] != z3_vars["v89"]),
    (z3_vars["v49"] != z3_vars["v99"]),
    (z3_vars["v51"] != z3_vars["v52"]),
    (z3_vars["v51"] != z3_vars["v53"]),
    (z3_vars["v51"] != z3_vars["v54"]),
    (z3_vars["v51"] != z3_vars["v55"]),
    (z3_vars["v51"] != z3_vars["v56"]),
    (z3_vars["v51"] != z3_vars["v57"]),
    (z3_vars["v51"] != z3_vars["v58"]),
    (z3_vars["v51"] != z3_vars["v59"]),
    (z3_vars["v51"] != z3_vars["v61"]),
    (z3_vars["v51"] != z3_vars["v62"]),
    (z3_vars["v51"] != z3_vars["v63"]),
    (z3_vars["v51"] != z3_vars["v71"]),
    (z3_vars["v51"] != z3_vars["v81"]),
    (z3_vars["v51"] != z3_vars["v91"]),
    (z3_vars["v52"] != z3_vars["v53"]),
    (z3_vars["v52"] != z3_vars["v54"]),
    (z3_vars["v52"] != z3_vars["v55"]),
    (z3_vars["v52"] != z3_vars["v56"]),
    (z3_vars["v52"] != z3_vars["v57"]),
    (z3_vars["v52"] != z3_vars["v58"]),
    (z3_vars["v52"] != z3_vars["v59"]),
    (z3_vars["v52"] != z3_vars["v61"]),
    (z3_vars["v52"] != z3_vars["v62"]),
    (z3_vars["v52"] != z3_vars["v63"]),
    (z3_vars["v52"] != z3_vars["v72"]),
    (z3_vars["v52"] != z3_vars["v82"]),
    (z3_vars["v52"] != z3_vars["v92"]),
    (z3_vars["v53"] != z3_vars["v54"]),
    (z3_vars["v53"] != z3_vars["v55"]),
    (z3_vars["v53"] != z3_vars["v56"]),
    (z3_vars["v53"] != z3_vars["v57"]),
    (z3_vars["v53"] != z3_vars["v58"]),
    (z3_vars["v53"] != z3_vars["v59"]),
    (z3_vars["v53"] != z3_vars["v61"]),
    (z3_vars["v53"] != z3_vars["v62"]),
    (z3_vars["v53"] != z3_vars["v63"]),
    (z3_vars["v53"] != z3_vars["v73"]),
    (z3_vars["v53"] != z3_vars["v83"]),
    (z3_vars["v53"] != z3_vars["v93"]),
    (z3_vars["v54"] != z3_vars["v55"]),
    (z3_vars["v54"] != z3_vars["v56"]),
    (z3_vars["v54"] != z3_vars["v57"]),
    (z3_vars["v54"] != z3_vars["v58"]),
    (z3_vars["v54"] != z3_vars["v59"]),
    (z3_vars["v54"] != z3_vars["v64"]),
    (z3_vars["v54"] != z3_vars["v65"]),
    (z3_vars["v54"] != z3_vars["v66"]),
    (z3_vars["v54"] != z3_vars["v74"]),
    (z3_vars["v54"] != z3_vars["v84"]),
    (z3_vars["v54"] != z3_vars["v94"]),
    (z3_vars["v55"] != z3_vars["v56"]),
    (z3_vars["v55"] != z3_vars["v57"]),
    (z3_vars["v55"] != z3_vars["v58"]),
    (z3_vars["v55"] != z3_vars["v59"]),
    (z3_vars["v55"] != z3_vars["v64"]),
    (z3_vars["v55"] != z3_vars["v65"]),
    (z3_vars["v55"] != z3_vars["v66"]),
    (z3_vars["v55"] != z3_vars["v75"]),
    (z3_vars["v55"] != z3_vars["v85"]),
    (z3_vars["v55"] != z3_vars["v95"]),
    (z3_vars["v56"] != z3_vars["v57"]),
    (z3_vars["v56"] != z3_vars["v58"]),
    (z3_vars["v56"] != z3_vars["v59"]),
    (z3_vars["v56"] != z3_vars["v64"]),
    (z3_vars["v56"] != z3_vars["v65"]),
    (z3_vars["v56"] != z3_vars["v66"]),
    (z3_vars["v56"] != z3_vars["v76"]),
    (z3_vars["v56"] != z3_vars["v86"]),
    (z3_vars["v56"] != z3_vars["v96"]),
    (z3_vars["v57"] != z3_vars["v58"]),
    (z3_vars["v57"] != z3_vars["v59"]),
    (z3_vars["v57"] != z3_vars["v67"]),
    (z3_vars["v57"] != z3_vars["v68"]),
    (z3_vars["v57"] != z3_vars["v69"]),
    (z3_vars["v57"] != z3_vars["v77"]),
    (z3_vars["v57"] != z3_vars["v87"]),
    (z3_vars["v57"] != z3_vars["v97"]),
    (z3_vars["v58"] != z3_vars["v59"]),
    (z3_vars["v58"] != z3_vars["v67"]),
    (z3_vars["v58"] != z3_vars["v68"]),
    (z3_vars["v58"] != z3_vars["v69"]),
    (z3_vars["v58"] != z3_vars["v78"]),
    (z3_vars["v58"] != z3_vars["v88"]),
    (z3_vars["v58"] != z3_vars["v98"]),
    (z3_vars["v59"] != z3_vars["v67"]),
    (z3_vars["v59"] != z3_vars["v68"]),
    (z3_vars["v59"] != z3_vars["v69"]),
    (z3_vars["v59"] != z3_vars["v79"]),
    (z3_vars["v59"] != z3_vars["v89"]),
    (z3_vars["v59"] != z3_vars["v99"]),
    (z3_vars["v61"] != z3_vars["v62"]),
    (z3_vars["v61"] != z3_vars["v63"]),
    (z3_vars["v61"] != z3_vars["v64"]),
    (z3_vars["v61"] != z3_vars["v65"]),
    (z3_vars["v61"] != z3_vars["v66"]),
    (z3_vars["v61"] != z3_vars["v67"]),
    (z3_vars["v61"] != z3_vars["v68"]),
    (z3_vars["v61"] != z3_vars["v69"]),
    (z3_vars["v61"] != z3_vars["v71"]),
    (z3_vars["v61"] != z3_vars["v81"]),
    (z3_vars["v61"] != z3_vars["v91"]),
    (z3_vars["v62"] != z3_vars["v63"]),
    (z3_vars["v62"] != z3_vars["v64"]),
    (z3_vars["v62"] != z3_vars["v65"]),
    (z3_vars["v62"] != z3_vars["v66"]),
    (z3_vars["v62"] != z3_vars["v67"]),
    (z3_vars["v62"] != z3_vars["v68"]),
    (z3_vars["v62"] != z3_vars["v69"]),
    (z3_vars["v62"] != z3_vars["v72"]),
    (z3_vars["v62"] != z3_vars["v82"]),
    (z3_vars["v62"] != z3_vars["v92"]),
    (z3_vars["v63"] != z3_vars["v64"]),
    (z3_vars["v63"] != z3_vars["v65"]),
    (z3_vars["v63"] != z3_vars["v66"]),
    (z3_vars["v63"] != z3_vars["v67"]),
    (z3_vars["v63"] != z3_vars["v68"]),
    (z3_vars["v63"] != z3_vars["v69"]),
    (z3_vars["v63"] != z3_vars["v73"]),
    (z3_vars["v63"] != z3_vars["v83"]),
    (z3_vars["v63"] != z3_vars["v93"]),
    (z3_vars["v64"] != z3_vars["v65"]),
    (z3_vars["v64"] != z3_vars["v66"]),
    (z3_vars["v64"] != z3_vars["v67"]),
    (z3_vars["v64"] != z3_vars["v68"]),
    (z3_vars["v64"] != z3_vars["v69"]),
    (z3_vars["v64"] != z3_vars["v74"]),
    (z3_vars["v64"] != z3_vars["v84"]),
    (z3_vars["v64"] != z3_vars["v94"]),
    (z3_vars["v65"] != z3_vars["v66"]),
    (z3_vars["v65"] != z3_vars["v67"]),
    (z3_vars["v65"] != z3_vars["v68"]),
    (z3_vars["v65"] != z3_vars["v69"]),
    (z3_vars["v65"] != z3_vars["v75"]),
    (z3_vars["v65"] != z3_vars["v85"]),
    (z3_vars["v65"] != z3_vars["v95"]),
    (z3_vars["v66"] != z3_vars["v67"]),
    (z3_vars["v66"] != z3_vars["v68"]),
    (z3_vars["v66"] != z3_vars["v69"]),
    (z3_vars["v66"] != z3_vars["v76"]),
    (z3_vars["v66"] != z3_vars["v86"]),
    (z3_vars["v66"] != z3_vars["v96"]),
    (z3_vars["v67"] != z3_vars["v68"]),
    (z3_vars["v67"] != z3_vars["v69"]),
    (z3_vars["v67"] != z3_vars["v77"]),
    (z3_vars["v67"] != z3_vars["v87"]),
    (z3_vars["v67"] != z3_vars["v97"]),
    (z3_vars["v68"] != z3_vars["v69"]),
    (z3_vars["v68"] != z3_vars["v78"]),
    (z3_vars["v68"] != z3_vars["v88"]),
    (z3_vars["v68"] != z3_vars["v98"]),
    (z3_vars["v69"] != z3_vars["v79"]),
    (z3_vars["v69"] != z3_vars["v89"]),
    (z3_vars["v69"] != z3_vars["v99"]),
    (z3_vars["v71"] != z3_vars["v72"]),
    (z3_vars["v71"] != z3_vars["v73"]),
    (z3_vars["v71"] != z3_vars["v74"]),
    (z3_vars["v71"] != z3_vars["v75"]),
    (z3_vars["v71"] != z3_vars["v76"]),
    (z3_vars["v71"] != z3_vars["v77"]),
    (z3_vars["v71"] != z3_vars["v78"]),
    (z3_vars["v71"] != z3_vars["v79"]),
    (z3_vars["v71"] != z3_vars["v81"]),
    (z3_vars["v71"] != z3_vars["v82"]),
    (z3_vars["v71"] != z3_vars["v83"]),
    (z3_vars["v71"] != z3_vars["v91"]),
    (z3_vars["v71"] != z3_vars["v92"]),
    (z3_vars["v71"] != z3_vars["v93"]),
    (z3_vars["v72"] != z3_vars["v73"]),
    (z3_vars["v72"] != z3_vars["v74"]),
    (z3_vars["v72"] != z3_vars["v75"]),
    (z3_vars["v72"] != z3_vars["v76"]),
    (z3_vars["v72"] != z3_vars["v77"]),
    (z3_vars["v72"] != z3_vars["v78"]),
    (z3_vars["v72"] != z3_vars["v79"]),
    (z3_vars["v72"] != z3_vars["v81"]),
    (z3_vars["v72"] != z3_vars["v82"]),
    (z3_vars["v72"] != z3_vars["v83"]),
    (z3_vars["v72"] != z3_vars["v91"]),
    (z3_vars["v72"] != z3_vars["v92"]),
    (z3_vars["v72"] != z3_vars["v93"]),
    (z3_vars["v73"] != z3_vars["v74"]),
    (z3_vars["v73"] != z3_vars["v75"]),
    (z3_vars["v73"] != z3_vars["v76"]),
    (z3_vars["v73"] != z3_vars["v77"]),
    (z3_vars["v73"] != z3_vars["v78"]),
    (z3_vars["v73"] != z3_vars["v79"]),
    (z3_vars["v73"] != z3_vars["v81"]),
    (z3_vars["v73"] != z3_vars["v82"]),
    (z3_vars["v73"] != z3_vars["v83"]),
    (z3_vars["v73"] != z3_vars["v91"]),
    (z3_vars["v73"] != z3_vars["v92"]),
    (z3_vars["v73"] != z3_vars["v93"]),
    (z3_vars["v74"] != z3_vars["v75"]),
    (z3_vars["v74"] != z3_vars["v76"]),
    (z3_vars["v74"] != z3_vars["v77"]),
    (z3_vars["v74"] != z3_vars["v78"]),
    (z3_vars["v74"] != z3_vars["v79"]),
    (z3_vars["v74"] != z3_vars["v84"]),
    (z3_vars["v74"] != z3_vars["v85"]),
    (z3_vars["v74"] != z3_vars["v86"]),
    (z3_vars["v74"] != z3_vars["v94"]),
    (z3_vars["v74"] != z3_vars["v95"]),
    (z3_vars["v74"] != z3_vars["v96"]),
    (z3_vars["v75"] != z3_vars["v76"]),
    (z3_vars["v75"] != z3_vars["v77"]),
    (z3_vars["v75"] != z3_vars["v78"]),
    (z3_vars["v75"] != z3_vars["v79"]),
    (z3_vars["v75"] != z3_vars["v84"]),
    (z3_vars["v75"] != z3_vars["v85"]),
    (z3_vars["v75"] != z3_vars["v86"]),
    (z3_vars["v75"] != z3_vars["v94"]),
    (z3_vars["v75"] != z3_vars["v95"]),
    (z3_vars["v75"] != z3_vars["v96"]),
    (z3_vars["v76"] != z3_vars["v77"]),
    (z3_vars["v76"] != z3_vars["v78"]),
    (z3_vars["v76"] != z3_vars["v79"]),
    (z3_vars["v76"] != z3_vars["v84"]),
    (z3_vars["v76"] != z3_vars["v85"]),
    (z3_vars["v76"] != z3_vars["v86"]),
    (z3_vars["v76"] != z3_vars["v94"]),
    (z3_vars["v76"] != z3_vars["v95"]),
    (z3_vars["v76"] != z3_vars["v96"]),
    (z3_vars["v77"] != z3_vars["v78"]),
    (z3_vars["v77"] != z3_vars["v79"]),
    (z3_vars["v77"] != z3_vars["v87"]),
    (z3_vars["v77"] != z3_vars["v88"]),
    (z3_vars["v77"] != z3_vars["v89"]),
    (z3_vars["v77"] != z3_vars["v97"]),
    (z3_vars["v77"] != z3_vars["v98"]),
    (z3_vars["v77"] != z3_vars["v99"]),
    (z3_vars["v78"] != z3_vars["v79"]),
    (z3_vars["v78"] != z3_vars["v87"]),
    (z3_vars["v78"] != z3_vars["v88"]),
    (z3_vars["v78"] != z3_vars["v89"]),
    (z3_vars["v78"] != z3_vars["v97"]),
    (z3_vars["v78"] != z3_vars["v98"]),
    (z3_vars["v78"] != z3_vars["v99"]),
    (z3_vars["v79"] != z3_vars["v87"]),
    (z3_vars["v79"] != z3_vars["v88"]),
    (z3_vars["v79"] != z3_vars["v89"]),
    (z3_vars["v79"] != z3_vars["v97"]),
    (z3_vars["v79"] != z3_vars["v98"]),
    (z3_vars["v79"] != z3_vars["v99"]),
    (z3_vars["v81"] != z3_vars["v82"]),
    (z3_vars["v81"] != z3_vars["v83"]),
    (z3_vars["v81"] != z3_vars["v84"]),
    (z3_vars["v81"] != z3_vars["v85"]),
    (z3_vars["v81"] != z3_vars["v86"]),
    (z3_vars["v81"] != z3_vars["v87"]),
    (z3_vars["v81"] != z3_vars["v88"]),
    (z3_vars["v81"] != z3_vars["v89"]),
    (z3_vars["v81"] != z3_vars["v91"]),
    (z3_vars["v81"] != z3_vars["v92"]),
    (z3_vars["v81"] != z3_vars["v93"]),
    (z3_vars["v82"] != z3_vars["v83"]),
    (z3_vars["v82"] != z3_vars["v84"]),
    (z3_vars["v82"] != z3_vars["v85"]),
    (z3_vars["v82"] != z3_vars["v86"]),
    (z3_vars["v82"] != z3_vars["v87"]),
    (z3_vars["v82"] != z3_vars["v88"]),
    (z3_vars["v82"] != z3_vars["v89"]),
    (z3_vars["v82"] != z3_vars["v91"]),
    (z3_vars["v82"] != z3_vars["v92"]),
    (z3_vars["v82"] != z3_vars["v93"]),
    (z3_vars["v83"] != z3_vars["v84"]),
    (z3_vars["v83"] != z3_vars["v85"]),
    (z3_vars["v83"] != z3_vars["v86"]),
    (z3_vars["v83"] != z3_vars["v87"]),
    (z3_vars["v83"] != z3_vars["v88"]),
    (z3_vars["v83"] != z3_vars["v89"]),
    (z3_vars["v83"] != z3_vars["v91"]),
    (z3_vars["v83"] != z3_vars["v92"]),
    (z3_vars["v83"] != z3_vars["v93"]),
    (z3_vars["v84"] != z3_vars["v85"]),
    (z3_vars["v84"] != z3_vars["v86"]),
    (z3_vars["v84"] != z3_vars["v87"]),
    (z3_vars["v84"] != z3_vars["v88"]),
    (z3_vars["v84"] != z3_vars["v89"]),
    (z3_vars["v84"] != z3_vars["v94"]),
    (z3_vars["v84"] != z3_vars["v95"]),
    (z3_vars["v84"] != z3_vars["v96"]),
    (z3_vars["v85"] != z3_vars["v86"]),
    (z3_vars["v85"] != z3_vars["v87"]),
    (z3_vars["v85"] != z3_vars["v88"]),
    (z3_vars["v85"] != z3_vars["v89"]),
    (z3_vars["v85"] != z3_vars["v94"]),
    (z3_vars["v85"] != z3_vars["v95"]),
    (z3_vars["v85"] != z3_vars["v96"]),
    (z3_vars["v86"] != z3_vars["v87"]),
    (z3_vars["v86"] != z3_vars["v88"]),
    (z3_vars["v86"] != z3_vars["v89"]),
    (z3_vars["v86"] != z3_vars["v94"]),
    (z3_vars["v86"] != z3_vars["v95"]),
    (z3_vars["v86"] != z3_vars["v96"]),
    (z3_vars["v87"] != z3_vars["v88"]),
    (z3_vars["v87"] != z3_vars["v89"]),
    (z3_vars["v87"] != z3_vars["v97"]),
    (z3_vars["v87"] != z3_vars["v98"]),
    (z3_vars["v87"] != z3_vars["v99"]),
    (z3_vars["v88"] != z3_vars["v89"]),
    (z3_vars["v88"] != z3_vars["v97"]),
    (z3_vars["v88"] != z3_vars["v98"]),
    (z3_vars["v88"] != z3_vars["v99"]),
    (z3_vars["v89"] != z3_vars["v97"]),
    (z3_vars["v89"] != z3_vars["v98"]),
    (z3_vars["v89"] != z3_vars["v99"]),
    (z3_vars["v91"] != z3_vars["v92"]),
    (z3_vars["v91"] != z3_vars["v93"]),
    (z3_vars["v91"] != z3_vars["v94"]),
    (z3_vars["v91"] != z3_vars["v95"]),
    (z3_vars["v91"] != z3_vars["v96"]),
    (z3_vars["v91"] != z3_vars["v97"]),
    (z3_vars["v91"] != z3_vars["v98"]),
    (z3_vars["v91"] != z3_vars["v99"]),
    (z3_vars["v92"] != z3_vars["v93"]),
    (z3_vars["v92"] != z3_vars["v94"]),
    (z3_vars["v92"] != z3_vars["v95"]),
    (z3_vars["v92"] != z3_vars["v96"]),
    (z3_vars["v92"] != z3_vars["v97"]),
    (z3_vars["v92"] != z3_vars["v98"]),
    (z3_vars["v92"] != z3_vars["v99"]),
    (z3_vars["v93"] != z3_vars["v94"]),
    (z3_vars["v93"] != z3_vars["v95"]),
    (z3_vars["v93"] != z3_vars["v96"]),
    (z3_vars["v93"] != z3_vars["v97"]),
    (z3_vars["v93"] != z3_vars["v98"]),
    (z3_vars["v93"] != z3_vars["v99"]),
    (z3_vars["v94"] != z3_vars["v95"]),
    (z3_vars["v94"] != z3_vars["v96"]),
    (z3_vars["v94"] != z3_vars["v97"]),
    (z3_vars["v94"] != z3_vars["v98"]),
    (z3_vars["v94"] != z3_vars["v99"]),
    (z3_vars["v95"] != z3_vars["v96"]),
    (z3_vars["v95"] != z3_vars["v97"]),
    (z3_vars["v95"] != z3_vars["v98"]),
    (z3_vars["v95"] != z3_vars["v99"]),
    (z3_vars["v96"] != z3_vars["v97"]),
    (z3_vars["v96"] != z3_vars["v98"]),
    (z3_vars["v96"] != z3_vars["v99"]),
    (z3_vars["v97"] != z3_vars["v98"]),
    (z3_vars["v97"] != z3_vars["v99"]),
    (z3_vars["v98"] != z3_vars["v99"]),
]


# 元の条件をZ3の制約として追加
b = [
    (z3_vars["v11"] != z3_vars["v12"]),
    (z3_vars["v11"] != z3_vars["v13"]),
    (z3_vars["v11"] != z3_vars["v14"]),
    (z3_vars["v11"] != z3_vars["v15"]),
    (z3_vars["v11"] != z3_vars["v16"]),
    (z3_vars["v11"] != z3_vars["v17"]),
    (z3_vars["v11"] != z3_vars["v18"]),
    (z3_vars["v11"] != z3_vars["v19"]),
    (z3_vars["v11"] != z3_vars["v21"]),
    (z3_vars["v11"] != z3_vars["v22"]),
    (z3_vars["v11"] != z3_vars["v23"]),
    (z3_vars["v11"] != z3_vars["v31"]),
    (z3_vars["v11"] != z3_vars["v32"]),
    (z3_vars["v11"] != z3_vars["v33"]),
    (z3_vars["v11"] != z3_vars["v41"]),
    (z3_vars["v11"] != z3_vars["v51"]),
    (z3_vars["v11"] != z3_vars["v61"]),
    (z3_vars["v11"] != z3_vars["v71"]),
    (z3_vars["v11"] != z3_vars["v81"]),
    (z3_vars["v11"] != z3_vars["v91"]),
    (z3_vars["v12"] != z3_vars["v13"]),
    (z3_vars["v12"] != z3_vars["v14"]),
    (z3_vars["v12"] != z3_vars["v15"]),
    (z3_vars["v12"] != z3_vars["v16"]),
    (z3_vars["v12"] != z3_vars["v17"]),
    (z3_vars["v12"] != z3_vars["v18"]),
    (z3_vars["v12"] != z3_vars["v19"]),
    (z3_vars["v12"] != z3_vars["v21"]),
    (z3_vars["v12"] != z3_vars["v22"]),
    (z3_vars["v12"] != z3_vars["v23"]),
    (z3_vars["v12"] != z3_vars["v31"]),
    (z3_vars["v12"] != z3_vars["v32"]),
    (z3_vars["v12"] != z3_vars["v33"]),
    (z3_vars["v12"] != z3_vars["v42"]),
    (z3_vars["v12"] != z3_vars["v52"]),
    (z3_vars["v12"] != z3_vars["v62"]),
    (z3_vars["v12"] != z3_vars["v72"]),
    (z3_vars["v12"] != z3_vars["v82"]),
    (z3_vars["v12"] != z3_vars["v92"]),
    (z3_vars["v13"] != z3_vars["v14"]),
    (z3_vars["v13"] != z3_vars["v15"]),
    (z3_vars["v13"] != z3_vars["v16"]),
    (z3_vars["v13"] != z3_vars["v17"]),
    (z3_vars["v13"] != z3_vars["v18"]),
    (z3_vars["v13"] != z3_vars["v19"]),
    (z3_vars["v13"] != z3_vars["v21"]),
    (z3_vars["v13"] != z3_vars["v22"]),
    (z3_vars["v13"] != z3_vars["v23"]),
    (z3_vars["v13"] != z3_vars["v31"]),
    (z3_vars["v13"] != z3_vars["v32"]),
    (z3_vars["v13"] != z3_vars["v33"]),
    (z3_vars["v13"] != z3_vars["v43"]),
    (z3_vars["v13"] != z3_vars["v53"]),
    (z3_vars["v13"] != z3_vars["v63"]),
    (z3_vars["v13"] != z3_vars["v73"]),
    (z3_vars["v13"] != z3_vars["v83"]),
    (z3_vars["v13"] != z3_vars["v93"]),
    (z3_vars["v14"] != z3_vars["v15"]),
    (z3_vars["v14"] != z3_vars["v16"]),
    (z3_vars["v14"] != z3_vars["v17"]),
    (z3_vars["v14"] != z3_vars["v18"]),
    (z3_vars["v14"] != z3_vars["v19"]),
    (z3_vars["v14"] != z3_vars["v24"]),
    (z3_vars["v14"] != z3_vars["v25"]),
    (z3_vars["v14"] != z3_vars["v26"]),
    (z3_vars["v14"] != z3_vars["v34"]),
    (z3_vars["v14"] != z3_vars["v35"]),
    (z3_vars["v14"] != z3_vars["v36"]),
    (z3_vars["v14"] != z3_vars["v44"]),
    (z3_vars["v14"] != z3_vars["v54"]),
    (z3_vars["v14"] != z3_vars["v64"]),
    (z3_vars["v14"] != z3_vars["v74"]),
    (z3_vars["v14"] != z3_vars["v84"]),
    (z3_vars["v14"] != z3_vars["v94"]),
    (z3_vars["v15"] != z3_vars["v16"]),
    (z3_vars["v15"] != z3_vars["v17"]),
    (z3_vars["v15"] != z3_vars["v18"]),
    (z3_vars["v15"] != z3_vars["v19"]),
    (z3_vars["v15"] != z3_vars["v24"]),
    (z3_vars["v15"] != z3_vars["v25"]),
    (z3_vars["v15"] != z3_vars["v26"]),
    (z3_vars["v15"] != z3_vars["v34"]),
    (z3_vars["v15"] != z3_vars["v35"]),
    (z3_vars["v15"] != z3_vars["v36"]),
    (z3_vars["v15"] != z3_vars["v45"]),
    (z3_vars["v15"] != z3_vars["v55"]),
    (z3_vars["v15"] != z3_vars["v65"]),
    (z3_vars["v15"] != z3_vars["v75"]),
    (z3_vars["v15"] != z3_vars["v85"]),
    (z3_vars["v15"] != z3_vars["v95"]),
    (z3_vars["v16"] != z3_vars["v17"]),
    (z3_vars["v16"] != z3_vars["v18"]),
    (z3_vars["v16"] != z3_vars["v19"]),
    (z3_vars["v16"] != z3_vars["v24"]),
    (z3_vars["v16"] != z3_vars["v25"]),
    (z3_vars["v16"] != z3_vars["v26"]),
    (z3_vars["v16"] != z3_vars["v34"]),
    (z3_vars["v16"] != z3_vars["v35"]),
    (z3_vars["v16"] != z3_vars["v36"]),
    (z3_vars["v16"] != z3_vars["v46"]),
    (z3_vars["v16"] != z3_vars["v56"]),
    (z3_vars["v16"] != z3_vars["v66"]),
    (z3_vars["v16"] != z3_vars["v76"]),
    (z3_vars["v16"] != z3_vars["v86"]),
    (z3_vars["v16"] != z3_vars["v96"]),
    (z3_vars["v17"] != z3_vars["v18"]),
    (z3_vars["v17"] != z3_vars["v19"]),
    (z3_vars["v17"] != z3_vars["v27"]),
    (z3_vars["v17"] != z3_vars["v28"]),
    (z3_vars["v17"] != z3_vars["v29"]),
    (z3_vars["v17"] != z3_vars["v37"]),
    (z3_vars["v17"] != z3_vars["v38"]),
    (z3_vars["v17"] != z3_vars["v39"]),
    (z3_vars["v17"] != z3_vars["v47"]),
    (z3_vars["v17"] != z3_vars["v57"]),
    (z3_vars["v17"] != z3_vars["v67"]),
    (z3_vars["v17"] != z3_vars["v77"]),
    (z3_vars["v17"] != z3_vars["v87"]),
    (z3_vars["v17"] != z3_vars["v97"]),
    (z3_vars["v18"] != z3_vars["v19"]),
    (z3_vars["v18"] != z3_vars["v27"]),
    (z3_vars["v18"] != z3_vars["v28"]),
    (z3_vars["v18"] != z3_vars["v29"]),
    (z3_vars["v18"] != z3_vars["v37"]),
    (z3_vars["v18"] != z3_vars["v38"]),
    (z3_vars["v18"] != z3_vars["v39"]),
    (z3_vars["v18"] != z3_vars["v48"]),
    (z3_vars["v18"] != z3_vars["v58"]),
    (z3_vars["v18"] != z3_vars["v68"]),
    (z3_vars["v18"] != z3_vars["v78"]),
    (z3_vars["v18"] != z3_vars["v88"]),
    (z3_vars["v18"] != z3_vars["v98"]),
    (z3_vars["v19"] != z3_vars["v27"]),
    (z3_vars["v19"] != z3_vars["v28"]),
    (z3_vars["v19"] != z3_vars["v29"]),
    (z3_vars["v19"] != z3_vars["v37"]),
    (z3_vars["v19"] != z3_vars["v38"]),
    (z3_vars["v19"] != z3_vars["v39"]),
    (z3_vars["v19"] != z3_vars["v49"]),
    (z3_vars["v19"] != z3_vars["v59"]),
    (z3_vars["v19"] != z3_vars["v69"]),
    (z3_vars["v19"] != z3_vars["v79"]),
    (z3_vars["v19"] != z3_vars["v89"]),
    (z3_vars["v19"] != z3_vars["v99"]),
    (z3_vars["v21"] != z3_vars["v22"]),
    (z3_vars["v21"] != z3_vars["v23"]),
    (z3_vars["v21"] != z3_vars["v24"]),
    (z3_vars["v21"] != z3_vars["v25"]),
    (z3_vars["v21"] != z3_vars["v26"]),
    (z3_vars["v21"] != z3_vars["v27"]),
    (z3_vars["v21"] != z3_vars["v28"]),
    (z3_vars["v21"] != z3_vars["v29"]),
    (z3_vars["v21"] != z3_vars["v31"]),
    (z3_vars["v21"] != z3_vars["v32"]),
    (z3_vars["v21"] != z3_vars["v33"]),
    (z3_vars["v21"] != z3_vars["v41"]),
    (z3_vars["v21"] != z3_vars["v51"]),
    (z3_vars["v21"] != z3_vars["v61"]),
    (z3_vars["v21"] != z3_vars["v71"]),
    (z3_vars["v21"] != z3_vars["v81"]),
    (z3_vars["v21"] != z3_vars["v91"]),
    (z3_vars["v22"] != z3_vars["v23"]),
    (z3_vars["v22"] != z3_vars["v24"]),
    (z3_vars["v22"] != z3_vars["v25"]),
    (z3_vars["v22"] != z3_vars["v26"]),
    (z3_vars["v22"] != z3_vars["v27"]),
    (z3_vars["v22"] != z3_vars["v28"]),
    (z3_vars["v22"] != z3_vars["v29"]),
    (z3_vars["v22"] != z3_vars["v31"]),
    (z3_vars["v22"] != z3_vars["v32"]),
    (z3_vars["v22"] != z3_vars["v33"]),
    (z3_vars["v22"] != z3_vars["v42"]),
    (z3_vars["v22"] != z3_vars["v52"]),
    (z3_vars["v22"] != z3_vars["v62"]),
    (z3_vars["v22"] != z3_vars["v72"]),
    (z3_vars["v22"] != z3_vars["v82"]),
    (z3_vars["v22"] != z3_vars["v92"]),
    (z3_vars["v23"] != z3_vars["v24"]),
    (z3_vars["v23"] != z3_vars["v25"]),
    (z3_vars["v23"] != z3_vars["v26"]),
    (z3_vars["v23"] != z3_vars["v27"]),
    (z3_vars["v23"] != z3_vars["v28"]),
    (z3_vars["v23"] != z3_vars["v29"]),
    (z3_vars["v23"] != z3_vars["v31"]),
    (z3_vars["v23"] != z3_vars["v32"]),
    (z3_vars["v23"] != z3_vars["v33"]),
    (z3_vars["v23"] != z3_vars["v43"]),
    (z3_vars["v23"] != z3_vars["v53"]),
    (z3_vars["v23"] != z3_vars["v63"]),
    (z3_vars["v23"] != z3_vars["v73"]),
    (z3_vars["v23"] != z3_vars["v83"]),
    (z3_vars["v23"] != z3_vars["v93"]),
    (z3_vars["v24"] != z3_vars["v25"]),
    (z3_vars["v24"] != z3_vars["v26"]),
    (z3_vars["v24"] != z3_vars["v27"]),
    (z3_vars["v24"] != z3_vars["v28"]),
    (z3_vars["v24"] != z3_vars["v29"]),
    (z3_vars["v24"] != z3_vars["v34"]),
    (z3_vars["v24"] != z3_vars["v35"]),
    (z3_vars["v24"] != z3_vars["v36"]),
    (z3_vars["v24"] != z3_vars["v44"]),
    (z3_vars["v24"] != z3_vars["v54"]),
    (z3_vars["v24"] != z3_vars["v64"]),
    (z3_vars["v24"] != z3_vars["v74"]),
    (z3_vars["v24"] != z3_vars["v84"]),
    (z3_vars["v24"] != z3_vars["v94"]),
    (z3_vars["v25"] != z3_vars["v26"]),
    (z3_vars["v25"] != z3_vars["v27"]),
    (z3_vars["v25"] != z3_vars["v28"]),
    (z3_vars["v25"] != z3_vars["v29"]),
    (z3_vars["v25"] != z3_vars["v34"]),
    (z3_vars["v25"] != z3_vars["v35"]),
    (z3_vars["v25"] != z3_vars["v36"]),
    (z3_vars["v25"] != z3_vars["v45"]),
    (z3_vars["v25"] != z3_vars["v55"]),
    (z3_vars["v25"] != z3_vars["v65"]),
    (z3_vars["v25"] != z3_vars["v75"]),
    (z3_vars["v25"] != z3_vars["v85"]),
    (z3_vars["v25"] != z3_vars["v95"]),
    (z3_vars["v26"] != z3_vars["v27"]),
    (z3_vars["v26"] != z3_vars["v28"]),
    (z3_vars["v26"] != z3_vars["v29"]),
    (z3_vars["v26"] != z3_vars["v34"]),
    (z3_vars["v26"] != z3_vars["v35"]),
    (z3_vars["v26"] != z3_vars["v36"]),
    (z3_vars["v26"] != z3_vars["v46"]),
    (z3_vars["v26"] != z3_vars["v56"]),
    (z3_vars["v26"] != z3_vars["v66"]),
    (z3_vars["v26"] != z3_vars["v76"]),
    (z3_vars["v26"] != z3_vars["v86"]),
    (z3_vars["v26"] != z3_vars["v96"]),
    (z3_vars["v27"] != z3_vars["v28"]),
    (z3_vars["v27"] != z3_vars["v29"]),
    (z3_vars["v27"] != z3_vars["v37"]),
    (z3_vars["v27"] != z3_vars["v38"]),
    (z3_vars["v27"] != z3_vars["v39"]),
    (z3_vars["v27"] != z3_vars["v47"]),
    (z3_vars["v27"] != z3_vars["v57"]),
    (z3_vars["v27"] != z3_vars["v67"]),
    (z3_vars["v27"] != z3_vars["v77"]),
    (z3_vars["v27"] != z3_vars["v87"]),
    (z3_vars["v27"] != z3_vars["v97"]),
    (z3_vars["v28"] != z3_vars["v29"]),
    (z3_vars["v28"] != z3_vars["v37"]),
    (z3_vars["v28"] != z3_vars["v38"]),
    (z3_vars["v28"] != z3_vars["v39"]),
    (z3_vars["v28"] != z3_vars["v48"]),
    (z3_vars["v28"] != z3_vars["v58"]),
    (z3_vars["v28"] != z3_vars["v68"]),
    (z3_vars["v28"] != z3_vars["v78"]),
    (z3_vars["v28"] != z3_vars["v88"]),
    (z3_vars["v28"] != z3_vars["v98"]),
    (z3_vars["v29"] != z3_vars["v37"]),
    (z3_vars["v29"] != z3_vars["v38"]),
    (z3_vars["v29"] != z3_vars["v39"]),
    (z3_vars["v29"] != z3_vars["v49"]),
    (z3_vars["v29"] != z3_vars["v59"]),
    (z3_vars["v29"] != z3_vars["v69"]),
    (z3_vars["v29"] != z3_vars["v79"]),
    (z3_vars["v29"] != z3_vars["v89"]),
    (z3_vars["v29"] != z3_vars["v99"]),
    (z3_vars["v31"] != z3_vars["v32"]),
    (z3_vars["v31"] != z3_vars["v33"]),
    (z3_vars["v31"] != z3_vars["v34"]),
    (z3_vars["v31"] != z3_vars["v35"]),
    (z3_vars["v31"] != z3_vars["v36"]),
    (z3_vars["v31"] != z3_vars["v37"]),
    (z3_vars["v31"] != z3_vars["v38"]),
    (z3_vars["v31"] != z3_vars["v39"]),
    (z3_vars["v31"] != z3_vars["v41"]),
    (z3_vars["v31"] != z3_vars["v51"]),
    (z3_vars["v31"] != z3_vars["v61"]),
    (z3_vars["v31"] != z3_vars["v71"]),
    (z3_vars["v31"] != z3_vars["v81"]),
    (z3_vars["v31"] != z3_vars["v91"]),
    (z3_vars["v32"] != z3_vars["v33"]),
    (z3_vars["v32"] != z3_vars["v34"]),
    (z3_vars["v32"] != z3_vars["v35"]),
    (z3_vars["v32"] != z3_vars["v36"]),
    (z3_vars["v32"] != z3_vars["v37"]),
    (z3_vars["v32"] != z3_vars["v38"]),
    (z3_vars["v32"] != z3_vars["v39"]),
    (z3_vars["v32"] != z3_vars["v42"]),
    (z3_vars["v32"] != z3_vars["v52"]),
    (z3_vars["v32"] != z3_vars["v62"]),
    (z3_vars["v32"] != z3_vars["v72"]),
    (z3_vars["v32"] != z3_vars["v82"]),
    (z3_vars["v32"] != z3_vars["v92"]),
    (z3_vars["v33"] != z3_vars["v34"]),
    (z3_vars["v33"] != z3_vars["v35"]),
    (z3_vars["v33"] != z3_vars["v36"]),
    (z3_vars["v33"] != z3_vars["v37"]),
    (z3_vars["v33"] != z3_vars["v38"]),
    (z3_vars["v33"] != z3_vars["v39"]),
    (z3_vars["v33"] != z3_vars["v43"]),
    (z3_vars["v33"] != z3_vars["v53"]),
    (z3_vars["v33"] != z3_vars["v63"]),
    (z3_vars["v33"] != z3_vars["v73"]),
    (z3_vars["v33"] != z3_vars["v83"]),
    (z3_vars["v33"] != z3_vars["v93"]),
    (z3_vars["v34"] != z3_vars["v35"]),
    (z3_vars["v34"] != z3_vars["v36"]),
    (z3_vars["v34"] != z3_vars["v37"]),
    (z3_vars["v34"] != z3_vars["v38"]),
    (z3_vars["v34"] != z3_vars["v39"]),
    (z3_vars["v34"] != z3_vars["v44"]),
    (z3_vars["v34"] != z3_vars["v54"]),
    (z3_vars["v34"] != z3_vars["v64"]),
    (z3_vars["v34"] != z3_vars["v74"]),
    (z3_vars["v34"] != z3_vars["v84"]),
    (z3_vars["v34"] != z3_vars["v94"]),
    (z3_vars["v35"] != z3_vars["v36"]),
    (z3_vars["v35"] != z3_vars["v37"]),
    (z3_vars["v35"] != z3_vars["v38"]),
    (z3_vars["v35"] != z3_vars["v39"]),
    (z3_vars["v35"] != z3_vars["v45"]),
    (z3_vars["v35"] != z3_vars["v55"]),
    (z3_vars["v35"] != z3_vars["v65"]),
    (z3_vars["v35"] != z3_vars["v75"]),
    (z3_vars["v35"] != z3_vars["v85"]),
    (z3_vars["v35"] != z3_vars["v95"]),
    (z3_vars["v36"] != z3_vars["v37"]),
    (z3_vars["v36"] != z3_vars["v38"]),
    (z3_vars["v36"] != z3_vars["v39"]),
    (z3_vars["v36"] != z3_vars["v46"]),
    (z3_vars["v36"] != z3_vars["v56"]),
    (z3_vars["v36"] != z3_vars["v66"]),
    (z3_vars["v36"] != z3_vars["v76"]),
    (z3_vars["v36"] != z3_vars["v86"]),
    (z3_vars["v36"] != z3_vars["v96"]),
    (z3_vars["v37"] != z3_vars["v38"]),
    (z3_vars["v37"] != z3_vars["v39"]),
    (z3_vars["v37"] != z3_vars["v47"]),
    (z3_vars["v37"] != z3_vars["v57"]),
    (z3_vars["v37"] != z3_vars["v67"]),
    (z3_vars["v37"] != z3_vars["v77"]),
    (z3_vars["v37"] != z3_vars["v87"]),
    (z3_vars["v37"] != z3_vars["v97"]),
    (z3_vars["v38"] != z3_vars["v39"]),
    (z3_vars["v38"] != z3_vars["v48"]),
    (z3_vars["v38"] != z3_vars["v58"]),
    (z3_vars["v38"] != z3_vars["v68"]),
    (z3_vars["v38"] != z3_vars["v78"]),
    (z3_vars["v38"] != z3_vars["v88"]),
    (z3_vars["v38"] != z3_vars["v98"]),
    (z3_vars["v39"] != z3_vars["v49"]),
    (z3_vars["v39"] != z3_vars["v59"]),
    (z3_vars["v39"] != z3_vars["v69"]),
    (z3_vars["v39"] != z3_vars["v79"]),
    (z3_vars["v39"] != z3_vars["v89"]),
    (z3_vars["v39"] != z3_vars["v99"]),
    (z3_vars["v41"] != z3_vars["v42"]),
    (z3_vars["v41"] != z3_vars["v43"]),
    (z3_vars["v41"] != z3_vars["v44"]),
    (z3_vars["v41"] != z3_vars["v45"]),
    (z3_vars["v41"] != z3_vars["v46"]),
    (z3_vars["v41"] != z3_vars["v47"]),
    (z3_vars["v41"] != z3_vars["v48"]),
    (z3_vars["v41"] != z3_vars["v49"]),
    (z3_vars["v41"] != z3_vars["v51"]),
    (z3_vars["v41"] != z3_vars["v52"]),
    (z3_vars["v41"] != z3_vars["v53"]),
    (z3_vars["v41"] != z3_vars["v61"]),
    (z3_vars["v41"] != z3_vars["v62"]),
    (z3_vars["v41"] != z3_vars["v63"]),
    (z3_vars["v41"] != z3_vars["v71"]),
    (z3_vars["v41"] != z3_vars["v81"]),
    (z3_vars["v41"] != z3_vars["v91"]),
    (z3_vars["v42"] != z3_vars["v43"]),
    (z3_vars["v42"] != z3_vars["v44"]),
    (z3_vars["v42"] != z3_vars["v45"]),
    (z3_vars["v42"] != z3_vars["v46"]),
    (z3_vars["v42"] != z3_vars["v47"]),
    (z3_vars["v42"] != z3_vars["v48"]),
    (z3_vars["v42"] != z3_vars["v49"]),
    (z3_vars["v42"] != z3_vars["v51"]),
    (z3_vars["v42"] != z3_vars["v52"]),
    (z3_vars["v42"] != z3_vars["v53"]),
    (z3_vars["v42"] != z3_vars["v61"]),
    (z3_vars["v42"] != z3_vars["v62"]),
    (z3_vars["v42"] != z3_vars["v63"]),
    (z3_vars["v42"] != z3_vars["v72"]),
    (z3_vars["v42"] != z3_vars["v82"]),
    (z3_vars["v42"] != z3_vars["v92"]),
    (z3_vars["v43"] != z3_vars["v44"]),
    (z3_vars["v43"] != z3_vars["v45"]),
    (z3_vars["v43"] != z3_vars["v46"]),
    (z3_vars["v43"] != z3_vars["v47"]),
    (z3_vars["v43"] != z3_vars["v48"]),
    (z3_vars["v43"] != z3_vars["v49"]),
    (z3_vars["v43"] != z3_vars["v51"]),
    (z3_vars["v43"] != z3_vars["v52"]),
    (z3_vars["v43"] != z3_vars["v53"]),
    (z3_vars["v43"] != z3_vars["v61"]),
    (z3_vars["v43"] != z3_vars["v62"]),
    (z3_vars["v43"] != z3_vars["v63"]),
    (z3_vars["v43"] != z3_vars["v73"]),
    (z3_vars["v43"] != z3_vars["v83"]),
    (z3_vars["v43"] != z3_vars["v93"]),
    (z3_vars["v44"] != z3_vars["v45"]),
    (z3_vars["v44"] != z3_vars["v46"]),
    (z3_vars["v44"] != z3_vars["v47"]),
    (z3_vars["v44"] != z3_vars["v48"]),
    (z3_vars["v44"] != z3_vars["v49"]),
    (z3_vars["v44"] != z3_vars["v54"]),
    (z3_vars["v44"] != z3_vars["v55"]),
    (z3_vars["v44"] != z3_vars["v56"]),
    (z3_vars["v44"] != z3_vars["v64"]),
    (z3_vars["v44"] != z3_vars["v65"]),
    (z3_vars["v44"] != z3_vars["v66"]),
    (z3_vars["v44"] != z3_vars["v74"]),
    (z3_vars["v44"] != z3_vars["v84"]),
    (z3_vars["v44"] != z3_vars["v94"]),
    (z3_vars["v45"] != z3_vars["v46"]),
    (z3_vars["v45"] != z3_vars["v47"]),
    (z3_vars["v45"] != z3_vars["v48"]),
    (z3_vars["v45"] != z3_vars["v49"]),
    (z3_vars["v45"] != z3_vars["v54"]),
    (z3_vars["v45"] != z3_vars["v55"]),
    (z3_vars["v45"] != z3_vars["v56"]),
    (z3_vars["v45"] != z3_vars["v64"]),
    (z3_vars["v45"] != z3_vars["v65"]),
    (z3_vars["v45"] != z3_vars["v66"]),
    (z3_vars["v45"] != z3_vars["v75"]),
    (z3_vars["v45"] != z3_vars["v85"]),
    (z3_vars["v45"] != z3_vars["v95"]),
    (z3_vars["v46"] != z3_vars["v47"]),
    (z3_vars["v46"] != z3_vars["v48"]),
    (z3_vars["v46"] != z3_vars["v49"]),
    (z3_vars["v46"] != z3_vars["v54"]),
    (z3_vars["v46"] != z3_vars["v55"]),
    (z3_vars["v46"] != z3_vars["v56"]),
    (z3_vars["v46"] != z3_vars["v64"]),
    (z3_vars["v46"] != z3_vars["v65"]),
    (z3_vars["v46"] != z3_vars["v66"]),
    (z3_vars["v46"] != z3_vars["v76"]),
    (z3_vars["v46"] != z3_vars["v86"]),
    (z3_vars["v46"] != z3_vars["v96"]),
    (z3_vars["v47"] != z3_vars["v48"]),
    (z3_vars["v47"] != z3_vars["v49"]),
    (z3_vars["v47"] != z3_vars["v57"]),
    (z3_vars["v47"] != z3_vars["v58"]),
    (z3_vars["v47"] != z3_vars["v59"]),
    (z3_vars["v47"] != z3_vars["v67"]),
    (z3_vars["v47"] != z3_vars["v68"]),
    (z3_vars["v47"] != z3_vars["v69"]),
    (z3_vars["v47"] != z3_vars["v77"]),
    (z3_vars["v47"] != z3_vars["v87"]),
    (z3_vars["v47"] != z3_vars["v97"]),
    (z3_vars["v48"] != z3_vars["v49"]),
    (z3_vars["v48"] != z3_vars["v57"]),
    (z3_vars["v48"] != z3_vars["v58"]),
    (z3_vars["v48"] != z3_vars["v59"]),
    (z3_vars["v48"] != z3_vars["v67"]),
    (z3_vars["v48"] != z3_vars["v68"]),
    (z3_vars["v48"] != z3_vars["v69"]),
    (z3_vars["v48"] != z3_vars["v78"]),
    (z3_vars["v48"] != z3_vars["v88"]),
    (z3_vars["v48"] != z3_vars["v98"]),
    (z3_vars["v49"] != z3_vars["v57"]),
    (z3_vars["v49"] != z3_vars["v58"]),
    (z3_vars["v49"] != z3_vars["v59"]),
    (z3_vars["v49"] != z3_vars["v67"]),
    (z3_vars["v49"] != z3_vars["v68"]),
    (z3_vars["v49"] != z3_vars["v69"]),
    (z3_vars["v49"] != z3_vars["v79"]),
    (z3_vars["v49"] != z3_vars["v89"]),
    (z3_vars["v49"] != z3_vars["v99"]),
    (z3_vars["v51"] != z3_vars["v52"]),
    (z3_vars["v51"] != z3_vars["v53"]),
    (z3_vars["v51"] != z3_vars["v54"]),
    (z3_vars["v51"] != z3_vars["v55"]),
    (z3_vars["v51"] != z3_vars["v56"]),
    (z3_vars["v51"] != z3_vars["v57"]),
    (z3_vars["v51"] != z3_vars["v58"]),
    (z3_vars["v51"] != z3_vars["v59"]),
    (z3_vars["v51"] != z3_vars["v61"]),
    (z3_vars["v51"] != z3_vars["v62"]),
    (z3_vars["v51"] != z3_vars["v63"]),
    (z3_vars["v51"] != z3_vars["v71"]),
    (z3_vars["v51"] != z3_vars["v81"]),
    (z3_vars["v51"] != z3_vars["v91"]),
    (z3_vars["v52"] != z3_vars["v53"]),
    (z3_vars["v52"] != z3_vars["v54"]),
    (z3_vars["v52"] != z3_vars["v55"]),
    (z3_vars["v52"] != z3_vars["v56"]),
    (z3_vars["v52"] != z3_vars["v57"]),
    (z3_vars["v52"] != z3_vars["v58"]),
    (z3_vars["v52"] != z3_vars["v59"]),
    (z3_vars["v52"] != z3_vars["v61"]),
    (z3_vars["v52"] != z3_vars["v62"]),
    (z3_vars["v52"] != z3_vars["v63"]),
    (z3_vars["v52"] != z3_vars["v72"]),
    (z3_vars["v52"] != z3_vars["v82"]),
    (z3_vars["v52"] != z3_vars["v92"]),
    (z3_vars["v53"] != z3_vars["v54"]),
    (z3_vars["v53"] != z3_vars["v55"]),
    (z3_vars["v53"] != z3_vars["v56"]),
    (z3_vars["v53"] != z3_vars["v57"]),
    (z3_vars["v53"] != z3_vars["v58"]),
    (z3_vars["v53"] != z3_vars["v59"]),
    (z3_vars["v53"] != z3_vars["v61"]),
    (z3_vars["v53"] != z3_vars["v62"]),
    (z3_vars["v53"] != z3_vars["v63"]),
    (z3_vars["v53"] != z3_vars["v73"]),
    (z3_vars["v53"] != z3_vars["v83"]),
    (z3_vars["v53"] != z3_vars["v93"]),
    (z3_vars["v54"] != z3_vars["v55"]),
    (z3_vars["v54"] != z3_vars["v56"]),
    (z3_vars["v54"] != z3_vars["v57"]),
    (z3_vars["v54"] != z3_vars["v58"]),
    (z3_vars["v54"] != z3_vars["v59"]),
    (z3_vars["v54"] != z3_vars["v64"]),
    (z3_vars["v54"] != z3_vars["v65"]),
    (z3_vars["v54"] != z3_vars["v66"]),
    (z3_vars["v54"] != z3_vars["v74"]),
    (z3_vars["v54"] != z3_vars["v84"]),
    (z3_vars["v54"] != z3_vars["v94"]),
    (z3_vars["v55"] != z3_vars["v56"]),
    (z3_vars["v55"] != z3_vars["v57"]),
    (z3_vars["v55"] != z3_vars["v58"]),
    (z3_vars["v55"] != z3_vars["v59"]),
    (z3_vars["v55"] != z3_vars["v64"]),
    (z3_vars["v55"] != z3_vars["v65"]),
    (z3_vars["v55"] != z3_vars["v66"]),
    (z3_vars["v55"] != z3_vars["v75"]),
    (z3_vars["v55"] != z3_vars["v85"]),
    (z3_vars["v55"] != z3_vars["v95"]),
    (z3_vars["v56"] != z3_vars["v57"]),
    (z3_vars["v56"] != z3_vars["v58"]),
    (z3_vars["v56"] != z3_vars["v59"]),
    (z3_vars["v56"] != z3_vars["v64"]),
    (z3_vars["v56"] != z3_vars["v65"]),
    (z3_vars["v56"] != z3_vars["v66"]),
    (z3_vars["v56"] != z3_vars["v76"]),
    (z3_vars["v56"] != z3_vars["v86"]),
    (z3_vars["v56"] != z3_vars["v96"]),
    (z3_vars["v57"] != z3_vars["v58"]),
    (z3_vars["v57"] != z3_vars["v59"]),
    (z3_vars["v57"] != z3_vars["v67"]),
    (z3_vars["v57"] != z3_vars["v68"]),
    (z3_vars["v57"] != z3_vars["v69"]),
    (z3_vars["v57"] != z3_vars["v77"]),
    (z3_vars["v57"] != z3_vars["v87"]),
    (z3_vars["v57"] != z3_vars["v97"]),
    (z3_vars["v58"] != z3_vars["v59"]),
    (z3_vars["v58"] != z3_vars["v67"]),
    (z3_vars["v58"] != z3_vars["v68"]),
    (z3_vars["v58"] != z3_vars["v69"]),
    (z3_vars["v58"] != z3_vars["v78"]),
    (z3_vars["v58"] != z3_vars["v88"]),
    (z3_vars["v58"] != z3_vars["v98"]),
    (z3_vars["v59"] != z3_vars["v67"]),
    (z3_vars["v59"] != z3_vars["v68"]),
    (z3_vars["v59"] != z3_vars["v69"]),
    (z3_vars["v59"] != z3_vars["v79"]),
    (z3_vars["v59"] != z3_vars["v89"]),
    (z3_vars["v59"] != z3_vars["v99"]),
    (z3_vars["v61"] != z3_vars["v62"]),
    (z3_vars["v61"] != z3_vars["v63"]),
    (z3_vars["v61"] != z3_vars["v64"]),
    (z3_vars["v61"] != z3_vars["v65"]),
    (z3_vars["v61"] != z3_vars["v66"]),
    (z3_vars["v61"] != z3_vars["v67"]),
    (z3_vars["v61"] != z3_vars["v68"]),
    (z3_vars["v61"] != z3_vars["v69"]),
    (z3_vars["v61"] != z3_vars["v71"]),
    (z3_vars["v61"] != z3_vars["v81"]),
    (z3_vars["v61"] != z3_vars["v91"]),
    (z3_vars["v62"] != z3_vars["v63"]),
    (z3_vars["v62"] != z3_vars["v64"]),
    (z3_vars["v62"] != z3_vars["v65"]),
    (z3_vars["v62"] != z3_vars["v66"]),
    (z3_vars["v62"] != z3_vars["v67"]),
    (z3_vars["v62"] != z3_vars["v68"]),
    (z3_vars["v62"] != z3_vars["v69"]),
    (z3_vars["v62"] != z3_vars["v72"]),
    (z3_vars["v62"] != z3_vars["v82"]),
    (z3_vars["v62"] != z3_vars["v92"]),
    (z3_vars["v63"] != z3_vars["v64"]),
    (z3_vars["v63"] != z3_vars["v65"]),
    (z3_vars["v63"] != z3_vars["v66"]),
    (z3_vars["v63"] != z3_vars["v67"]),
    (z3_vars["v63"] != z3_vars["v68"]),
    (z3_vars["v63"] != z3_vars["v69"]),
    (z3_vars["v63"] != z3_vars["v73"]),
    (z3_vars["v63"] != z3_vars["v83"]),
    (z3_vars["v63"] != z3_vars["v93"]),
    (z3_vars["v64"] != z3_vars["v65"]),
    (z3_vars["v64"] != z3_vars["v66"]),
    (z3_vars["v64"] != z3_vars["v67"]),
    (z3_vars["v64"] != z3_vars["v68"]),
    (z3_vars["v64"] != z3_vars["v69"]),
    (z3_vars["v64"] != z3_vars["v74"]),
    (z3_vars["v64"] != z3_vars["v84"]),
    (z3_vars["v64"] != z3_vars["v94"]),
    (z3_vars["v65"] != z3_vars["v66"]),
    (z3_vars["v65"] != z3_vars["v67"]),
    (z3_vars["v65"] != z3_vars["v68"]),
    (z3_vars["v65"] != z3_vars["v69"]),
    (z3_vars["v65"] != z3_vars["v75"]),
    (z3_vars["v65"] != z3_vars["v85"]),
    (z3_vars["v65"] != z3_vars["v95"]),
    (z3_vars["v66"] != z3_vars["v67"]),
    (z3_vars["v66"] != z3_vars["v68"]),
    (z3_vars["v66"] != z3_vars["v69"]),
    (z3_vars["v66"] != z3_vars["v76"]),
    (z3_vars["v66"] != z3_vars["v86"]),
    (z3_vars["v66"] != z3_vars["v96"]),
    (z3_vars["v67"] != z3_vars["v68"]),
    (z3_vars["v67"] != z3_vars["v69"]),
    (z3_vars["v67"] != z3_vars["v77"]),
    (z3_vars["v67"] != z3_vars["v87"]),
    (z3_vars["v67"] != z3_vars["v97"]),
    (z3_vars["v68"] != z3_vars["v69"]),
    (z3_vars["v68"] != z3_vars["v78"]),
    (z3_vars["v68"] != z3_vars["v88"]),
    (z3_vars["v68"] != z3_vars["v98"]),
    (z3_vars["v69"] != z3_vars["v79"]),
    (z3_vars["v69"] != z3_vars["v89"]),
    (z3_vars["v69"] != z3_vars["v99"]),
    (z3_vars["v71"] != z3_vars["v72"]),
    (z3_vars["v71"] != z3_vars["v73"]),
    (z3_vars["v71"] != z3_vars["v74"]),
    (z3_vars["v71"] != z3_vars["v75"]),
    (z3_vars["v71"] != z3_vars["v76"]),
    (z3_vars["v71"] != z3_vars["v77"]),
    (z3_vars["v71"] != z3_vars["v78"]),
    (z3_vars["v71"] != z3_vars["v79"]),
    (z3_vars["v71"] != z3_vars["v81"]),
    (z3_vars["v71"] != z3_vars["v82"]),
    (z3_vars["v71"] != z3_vars["v83"]),
    (z3_vars["v71"] != z3_vars["v91"]),
    (z3_vars["v71"] != z3_vars["v92"]),
    (z3_vars["v71"] != z3_vars["v93"]),
    (z3_vars["v72"] != z3_vars["v73"]),
    (z3_vars["v72"] != z3_vars["v74"]),
    (z3_vars["v72"] != z3_vars["v75"]),
    (z3_vars["v72"] != z3_vars["v76"]),
    (z3_vars["v72"] != z3_vars["v77"]),
    (z3_vars["v72"] != z3_vars["v78"]),
    (z3_vars["v72"] != z3_vars["v79"]),
    (z3_vars["v72"] != z3_vars["v81"]),
    (z3_vars["v72"] != z3_vars["v82"]),
    (z3_vars["v72"] != z3_vars["v83"]),
    (z3_vars["v72"] != z3_vars["v91"]),
    (z3_vars["v72"] != z3_vars["v92"]),
    (z3_vars["v72"] != z3_vars["v93"]),
    (z3_vars["v73"] != z3_vars["v74"]),
    (z3_vars["v73"] != z3_vars["v75"]),
    (z3_vars["v73"] != z3_vars["v76"]),
    (z3_vars["v73"] != z3_vars["v77"]),
    (z3_vars["v73"] != z3_vars["v78"]),
    (z3_vars["v73"] != z3_vars["v79"]),
    (z3_vars["v73"] != z3_vars["v81"]),
    (z3_vars["v73"] != z3_vars["v82"]),
    (z3_vars["v73"] != z3_vars["v83"]),
    (z3_vars["v73"] != z3_vars["v91"]),
    (z3_vars["v73"] != z3_vars["v92"]),
    (z3_vars["v73"] != z3_vars["v93"]),
    (z3_vars["v74"] != z3_vars["v75"]),
    (z3_vars["v74"] != z3_vars["v76"]),
    (z3_vars["v74"] != z3_vars["v77"]),
    (z3_vars["v74"] != z3_vars["v78"]),
    (z3_vars["v74"] != z3_vars["v79"]),
    (z3_vars["v74"] != z3_vars["v84"]),
    (z3_vars["v74"] != z3_vars["v85"]),
    (z3_vars["v74"] != z3_vars["v86"]),
    (z3_vars["v74"] != z3_vars["v94"]),
    (z3_vars["v74"] != z3_vars["v95"]),
    (z3_vars["v74"] != z3_vars["v96"]),
    (z3_vars["v75"] != z3_vars["v76"]),
    (z3_vars["v75"] != z3_vars["v77"]),
    (z3_vars["v75"] != z3_vars["v78"]),
    (z3_vars["v75"] != z3_vars["v79"]),
    (z3_vars["v75"] != z3_vars["v84"]),
    (z3_vars["v75"] != z3_vars["v85"]),
    (z3_vars["v75"] != z3_vars["v86"]),
    (z3_vars["v75"] != z3_vars["v94"]),
    (z3_vars["v75"] != z3_vars["v95"]),
    (z3_vars["v75"] != z3_vars["v96"]),
    (z3_vars["v76"] != z3_vars["v77"]),
    (z3_vars["v76"] != z3_vars["v78"]),
    (z3_vars["v76"] != z3_vars["v79"]),
    (z3_vars["v76"] != z3_vars["v84"]),
    (z3_vars["v76"] != z3_vars["v85"]),
    (z3_vars["v76"] != z3_vars["v86"]),
    (z3_vars["v76"] != z3_vars["v94"]),
    (z3_vars["v76"] != z3_vars["v95"]),
    (z3_vars["v76"] != z3_vars["v96"]),
    (z3_vars["v77"] != z3_vars["v78"]),
    (z3_vars["v77"] != z3_vars["v79"]),
    (z3_vars["v77"] != z3_vars["v87"]),
    (z3_vars["v77"] != z3_vars["v88"]),
    (z3_vars["v77"] != z3_vars["v89"]),
    (z3_vars["v77"] != z3_vars["v97"]),
    (z3_vars["v77"] != z3_vars["v98"]),
    (z3_vars["v77"] != z3_vars["v99"]),
    (z3_vars["v78"] != z3_vars["v79"]),
    (z3_vars["v78"] != z3_vars["v87"]),
    (z3_vars["v78"] != z3_vars["v88"]),
    (z3_vars["v78"] != z3_vars["v89"]),
    (z3_vars["v78"] != z3_vars["v97"]),
    (z3_vars["v78"] != z3_vars["v98"]),
    (z3_vars["v78"] != z3_vars["v99"]),
    (z3_vars["v79"] != z3_vars["v87"]),
    (z3_vars["v79"] != z3_vars["v88"]),
    (z3_vars["v79"] != z3_vars["v89"]),
    (z3_vars["v79"] != z3_vars["v97"]),
    (z3_vars["v79"] != z3_vars["v98"]),
    (z3_vars["v79"] != z3_vars["v99"]),
    (z3_vars["v81"] != z3_vars["v82"]),
    (z3_vars["v81"] != z3_vars["v83"]),
    (z3_vars["v81"] != z3_vars["v84"]),
    (z3_vars["v81"] != z3_vars["v85"]),
    (z3_vars["v81"] != z3_vars["v86"]),
    (z3_vars["v81"] != z3_vars["v87"]),
    (z3_vars["v81"] != z3_vars["v88"]),
    (z3_vars["v81"] != z3_vars["v89"]),
    (z3_vars["v81"] != z3_vars["v91"]),
    (z3_vars["v81"] != z3_vars["v92"]),
    (z3_vars["v81"] != z3_vars["v93"]),
    (z3_vars["v82"] != z3_vars["v83"]),
    (z3_vars["v82"] != z3_vars["v84"]),
    (z3_vars["v82"] != z3_vars["v85"]),
    (z3_vars["v82"] != z3_vars["v86"]),
    (z3_vars["v82"] != z3_vars["v87"]),
    (z3_vars["v82"] != z3_vars["v88"]),
    (z3_vars["v82"] != z3_vars["v89"]),
    (z3_vars["v82"] != z3_vars["v91"]),
    (z3_vars["v82"] != z3_vars["v92"]),
    (z3_vars["v82"] != z3_vars["v93"]),
    (z3_vars["v83"] != z3_vars["v84"]),
    (z3_vars["v83"] != z3_vars["v85"]),
    (z3_vars["v83"] != z3_vars["v86"]),
    (z3_vars["v83"] != z3_vars["v87"]),
    (z3_vars["v83"] != z3_vars["v88"]),
    (z3_vars["v83"] != z3_vars["v89"]),
    (z3_vars["v83"] != z3_vars["v91"]),
    (z3_vars["v83"] != z3_vars["v92"]),
    (z3_vars["v83"] != z3_vars["v93"]),
    (z3_vars["v84"] != z3_vars["v85"]),
    (z3_vars["v84"] != z3_vars["v86"]),
    (z3_vars["v84"] != z3_vars["v87"]),
    (z3_vars["v84"] != z3_vars["v88"]),
    (z3_vars["v84"] != z3_vars["v89"]),
    (z3_vars["v84"] != z3_vars["v94"]),
    (z3_vars["v84"] != z3_vars["v95"]),
    (z3_vars["v84"] != z3_vars["v96"]),
    (z3_vars["v85"] != z3_vars["v86"]),
    (z3_vars["v85"] != z3_vars["v87"]),
    (z3_vars["v85"] != z3_vars["v88"]),
    (z3_vars["v85"] != z3_vars["v89"]),
    (z3_vars["v85"] != z3_vars["v94"]),
    (z3_vars["v85"] != z3_vars["v95"]),
    (z3_vars["v85"] != z3_vars["v96"]),
    (z3_vars["v86"] != z3_vars["v87"]),
    (z3_vars["v86"] != z3_vars["v88"]),
    (z3_vars["v86"] != z3_vars["v89"]),
    (z3_vars["v86"] != z3_vars["v94"]),
    (z3_vars["v86"] != z3_vars["v95"]),
    (z3_vars["v86"] != z3_vars["v96"]),
    (z3_vars["v87"] != z3_vars["v88"]),
    (z3_vars["v87"] != z3_vars["v89"]),
    (z3_vars["v87"] != z3_vars["v97"]),
    (z3_vars["v87"] != z3_vars["v98"]),
    (z3_vars["v87"] != z3_vars["v99"]),
    (z3_vars["v88"] != z3_vars["v89"]),
    (z3_vars["v88"] != z3_vars["v97"]),
    (z3_vars["v88"] != z3_vars["v98"]),
    (z3_vars["v88"] != z3_vars["v99"]),
    (z3_vars["v89"] != z3_vars["v97"]),
    (z3_vars["v89"] != z3_vars["v98"]),
    (z3_vars["v89"] != z3_vars["v99"]),
    (z3_vars["v91"] != z3_vars["v92"]),
    (z3_vars["v91"] != z3_vars["v93"]),
    (z3_vars["v91"] != z3_vars["v94"]),
    (z3_vars["v91"] != z3_vars["v95"]),
    (z3_vars["v91"] != z3_vars["v96"]),
    (z3_vars["v91"] != z3_vars["v97"]),
    (z3_vars["v91"] != z3_vars["v98"]),
    (z3_vars["v91"] != z3_vars["v99"]),
    (z3_vars["v92"] != z3_vars["v93"]),
    (z3_vars["v92"] != z3_vars["v94"]),
    (z3_vars["v92"] != z3_vars["v95"]),
    (z3_vars["v92"] != z3_vars["v96"]),
    (z3_vars["v92"] != z3_vars["v97"]),
    (z3_vars["v92"] != z3_vars["v98"]),
    (z3_vars["v92"] != z3_vars["v99"]),
    (z3_vars["v93"] != z3_vars["v94"]),
    (z3_vars["v93"] != z3_vars["v95"]),
    (z3_vars["v93"] != z3_vars["v96"]),
    (z3_vars["v93"] != z3_vars["v97"]),
    (z3_vars["v93"] != z3_vars["v98"]),
    (z3_vars["v93"] != z3_vars["v99"]),
    (z3_vars["v94"] != z3_vars["v95"]),
    (z3_vars["v94"] != z3_vars["v96"]),
    (z3_vars["v94"] != z3_vars["v97"]),
    (z3_vars["v94"] != z3_vars["v98"]),
    (z3_vars["v94"] != z3_vars["v99"]),
    (z3_vars["v95"] != z3_vars["v96"]),
    (z3_vars["v95"] != z3_vars["v97"]),
    (z3_vars["v95"] != z3_vars["v98"]),
    (z3_vars["v95"] != z3_vars["v99"]),
    (z3_vars["v96"] != z3_vars["v97"]),
    (z3_vars["v96"] != z3_vars["v98"]),
    (z3_vars["v96"] != z3_vars["v99"]),
    (z3_vars["v97"] != z3_vars["v98"]),
    (z3_vars["v97"] != z3_vars["v99"]),
    (z3_vars["v98"] != z3_vars["v99"]),
]
print("board constraints: ", len(conditions))

# (v17 = 6)) & (v18 = 8)) & (v25 = 7)) & (v26 = 3)) & (v29 = 9)) & (v31 = 3)) & (v33 = 9)) & (v38 = 4)) & (v39 = 5)) & (v41 = 4)) & (v42 = 9)) & (v51 = 8)) & (v53 = 3)) & (v55 = 5)) & (v57 = 9)) & (v59 = 2)) & (v68 = 3)) & (v69 = 6)) & (v71 = 9)) & (v72 = 6)) & (v77 = 3)) & (v79 = 8)) & (v81 = 7)) & (v84 = 6)) & (v85 = 8)) & (v92 = 2)) & (v93 = 8)) 
constraints = [
    z3_vars["v17"] == 6,
    z3_vars["v18"] == 8,
    z3_vars["v25"] == 7,
    z3_vars["v26"] == 3,
    z3_vars["v29"] == 9,
    z3_vars["v31"] == 3,
    z3_vars["v33"] == 9,
    z3_vars["v38"] == 4,
    z3_vars["v39"] == 5,
    z3_vars["v41"] == 4,
    z3_vars["v42"] == 9,
    z3_vars["v51"] == 8,
    z3_vars["v53"] == 3,
    z3_vars["v55"] == 5,
    z3_vars["v57"] == 9,
    z3_vars["v59"] == 2,
    z3_vars["v68"] == 3,
    z3_vars["v69"] == 6,
    z3_vars["v71"] == 9,
    z3_vars["v72"] == 6,
    z3_vars["v77"] == 3,
    z3_vars["v79"] == 8,
    z3_vars["v81"] == 7,
    z3_vars["v84"] == 6,
    z3_vars["v85"] == 8,
    z3_vars["v92"] == 2,
    z3_vars["v93"] == 8
]
print(len(constraints))

conditions.extend(constraints)

for v in variables:
    conditions.append(1 <= z3_vars[v])
    conditions.append(9 >= z3_vars[v])

def has_solution(constraints):
    # Solve the constraints
    solver = Solver()
    solver.add(constraints)

    result = solver.check()
    print(result)
    if result == sat:
        # print(
        return True
    else:
        # print("No solution found")
        return False

x = 0
print("variables:", len(variables))
for v in reversed(variables):
    print(v)
    for d in range(1, 10):
        tmp = copy.copy(conditions)
        tmp.append(z3_vars[v] == d)

        if (has_solution(tmp)):
            print(v, d)
            original_constraints = tmp
            x = x * 9 + (d - 1)
            conditions.append(z3_vars[v] == d)
            break

    #tmp.append(v)
print(x)
# Out:
# board constraints:  810
# 27
# variables: 81
# v99
# unsat
# unsat
# unsat
# unsat
# unsat
# unsat
# sat
# v99 7
# v98
# unsat
# unsat
# unsat
# unsat
# unsat
# sat
# v98 6
# v97
# sat
# v97 1
# v96
# unsat
# unsat
# unsat
# sat
# v96 4
# v95
# unsat
# unsat
# sat
# v95 3
# v94
# unsat
# unsat
# unsat
# unsat
# unsat
# unsat
# unsat
# unsat
# sat
# v94 9
# v93
# unsat
# unsat
# unsat
# unsat
# unsat
# unsat
# unsat
# sat
# v93 8
# v92
# unsat
# sat
# v92 2
# v91
# unsat
# unsat
# unsat
# unsat
# sat
# v91 5
# v89
# unsat
# unsat
# unsat
# sat
# v89 4
# v88
# unsat
# unsat
# unsat
# unsat
# unsat
# unsat
# unsat
# unsat
# sat
# v88 9
# v87
# unsat
# unsat
# unsat
# unsat
# sat
# v87 5
# v86
# unsat
# sat
# v86 2
# v85
# unsat
# unsat
# unsat
# unsat
# unsat
# unsat
# unsat
# sat
# v85 8
# v84
# unsat
# unsat
# unsat
# unsat
# unsat
# sat
# v84 6
# v83
# sat
# v83 1
# v82
# unsat
# unsat
# sat
# v82 3
# v81
# unsat
# unsat
# unsat
# unsat
# unsat
# unsat
# sat
# v81 7
# v79
# unsat
# ...

# %%
t = 143321994060012662499343767757306951090876131119198714074253035355889423765252
for i in range(9):
    for j in range(9):
        print(t % 9 + 1, end=" ")
        t //= 9
    print()
# Out:
# 1 7 2 5 4 9 6 8 3
# 6 4 5 8 7 3 2 1 9
# 3 8 9 2 6 1 7 4 5
# 4 9 6 3 2 7 8 5 1
# 8 1 3 4 5 6 9 7 2
# 2 5 7 1 9 8 4 3 6
# 9 6 4 7 1 5 3 2 8
# 7 3 1 6 8 2 5 9 4
# 5 2 8 9 3 4 1 6 7
